# %%
import os
import re
import matplotlib.pylab as plt
from labellines import labelLine, labelLines
import seaborn as sns
import numpy as np

# %%
############ color stuff (https://medium.com/@BrendanArtley/matplotlib-color-gradients-21374910584b) ###############

def hex_to_RGB(hex_str):
    """ #FFFFFF -> [255,255,255]"""
    #Pass 16 to the integer function for change of base
    return [int(hex_str[i:i+2], 16) for i in range(1,6,2)]

def get_color_gradient(c1, c2, n):
    """
    Given two hex colors, returns a color gradient
    with n colors.
    """
    assert n > 1
    c1_rgb = np.array(hex_to_RGB(c1))/255
    c2_rgb = np.array(hex_to_RGB(c2))/255
    mix_pcts = [x/(n-1) for x in range(n)]
    rgb_colors = [((1-mix)*c1_rgb + (mix*c2_rgb)) for mix in mix_pcts]
    return ["#" + "".join([format(int(round(val*255)), "02x") for val in item]) for item in rgb_colors]

#color1 = "#8A5AC2"
color2 = "#3575D5"

color1 = '#FB575D'
#color2 = '#15251B'

# a = [120,121,122,123,124,125,126]

# get_color_gradient(color1, color2, len(a))

# %%
directory = './flamespeeds'

list_of_blends = [file for file in os.listdir(directory) if re.search('([\S]+)\.csv', file)]
colors = get_color_gradient(color1, color2, len(list_of_blends ))

fig = plt.figure()


#add in NIST model

volfrac_of_btp = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
# fracs = [x*100 for x in volfrac_of_btp]
flamespeeds = [0.40875258644125273,0.16966926524557838,0.09506093355318838,0.07327356686247803,0.061265194613989125,0.052793644460558425,0.04667136814266926,0.04106928680179994,0.0365547487209216,0.03252991701877541]
speeds_ = [x*100 for x in flamespeeds]



for color, file in zip(colors, list_of_blends): 
    
        fig2 = plt.figure()
        match = re.search('([\S]+)\.csv', file)
        
        
        
#           with open(f'./flamespeeds/132_133/{file}','r') as f: 
#             values = f.readlines()
#             new_fractions = values[0].replace('[','').replace(']','')
#             new_speeds = values[1].replace('[','').replace(']','')
#         BTP_fractions = [float(x) for x in new_fractions.split(',')]
#        # print(values[1].split(','))
#         speed = [float(x) for x in new_speeds.split(',')]
#         speeds = [x*100 for x in speed]
        


        with open(f'./flamespeeds/{file}','r') as f: 
            values = f.readlines()
            new_fractions = values[0].replace('[','').replace(']','')
            new_speeds = values[1].replace('[','').replace(']','')
        BTP_fractions = [float(x) for x in new_fractions.split(',')]
       # print(values[1].split(','))
        speed = [float(x) for x in new_speeds.split(',')]
        speeds = [x*100 for x in speed]
        
        print(speeds)
        


        #plotting 
        
        ax1 = fig.add_subplot(111)
        ax1.plot(BTP_fractions, speeds, '.-', c=f'{color}', label=str(match.group(1)))

        plt.xlabel('2-BTP volume fraction')
        plt.ylabel('Su (cm/s)')
        plt.title('Flame Speeds of Different Model Sizes (120-140)')
        ax1.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))
        
        ax2 = fig2.add_subplot(111)
        ax2.plot(BTP_fractions, speeds, '.-', c=f'{color}', label=str(match.group(1)))
        ax2.plot(volfrac_of_btp, speeds_, '-', c='g', label='NIST, 298K' )
        ax2.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))
        print(f'added in {match.group(1)}')


ax1 = fig.add_subplot(111)

ax1.plot(volfrac_of_btp, speeds_, '-', c='g', label='NIST, 298K' )
ax1.plot(exper_fracs, exper_speeds, '-', c='b', label='NIST, experimental data from figure, 298K' )
ax1.plot(NIST_fracs, NIST_speeds, '-', c='r', label='NIST model data from figure, 298K' )

plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Flame Speeds of Different Model Sizes (120-140)')
ax1.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))
# Out:
# [36.8361183236519, 31.05076283048821, 26.951281729091647, 22.78994661302301, 18.438916925493327, 14.290877857789642, 10.739053748308903, 8.41843877033093, 6.8649939954525525, 5.698769526580049]
# added in flamespeed_copy_chem_.cti
# [36.83605154709084, 31.052061806203668, 26.95923084629806, 22.75950036960309, 18.472780196049264, 14.335895845636145, 10.79068443583775, 8.4618573687353, 6.898722963649398, 5.710027253542644]
# added in flamespeed_copy_chem_1285.cti
# [36.83298047888251, 31.042183035746966, 26.937101115720946, 22.77170807342746, 18.4188200734385, 14.27167193326776, 10.723439647279761, 8.407770674418934, 6.857802938050374, 5.693918185434621]
# added in flamespeed_copy_chem_1321.cti
# [36.60782159691382, 31.043489917068435, 26.944930230550234, 22.738207372357127, 18.45104011152726, 14.313915048254952, 10.771713854709274, 8.448210655182343, 6.889125305688632, 5.703485015415277]
# added in flamespeed_copy_chem_1321_1285.cti
# ...

# %% [markdown]
# # REPORT

# %% [markdown]
# How do I know that my script actually changed the kinetics of the specified reactions?
#     - check with compare reactions
#     - pretty sure this is the problem. From slurms, it doesnt look like the flamespeed values are changing at all
#     - ***checked chemkin files are they are the same! so reaction wasn't changed!***
#
#
#
#     -could it be that I didn't include the transport?
# If I did actually change the kinetics of the ones that I wanted to, maybe there's other reactions in Nora's biggest model (145 species) that is causing the flamespeed to still be too high?

# %% [markdown]
# # Plotting Add_Delete 1285

# %%
fig = plt.figure()


#add in NIST model

volfrac_of_btp = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
# fracs = [x*100 for x in volfrac_of_btp]
flamespeeds = [0.40875258644125273,0.16966926524557838,0.09506093355318838,0.07327356686247803,0.061265194613989125,0.052793644460558425,0.04667136814266926,0.04106928680179994,0.0365547487209216,0.03252991701877541]
speeds_ = [x*100 for x in flamespeeds]


add_del_fractions= [0.0, 0.0034246488829682868, 0.006825921381900819, 0.01020405603073009, 0.01355928812903828, 0.016891849796691408, 0.02020197002736977, 0.023489874741020596, 0.02675578683525816, 0.029999926235735837]
add_del_spds = [0.36835150190837607, 0.3104550489099243, 0.2693097549838843, 0.22746244409749006, 0.183387868590958, 0.14150125479556938, 0.10557372048215469, 0.08234195715378544, 0.06677349862836003, 0.054664509104817176]
add_del_speeds = [x*100 for x in add_del_spds]

ax1 = fig.add_subplot(111)

ax1.plot(add_del_fractions, add_del_speeds, '-', c='m', label='Add_Delete, 298K' )
ax1.plot(volfrac_of_btp, speeds_, '-', c='g', label='NIST, 298K' )


plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Flame Speeds of Different Model Sizes (120-140)')
ax1.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))

# %% [markdown]
# Plotting Add_Delete 869

# %%
#Plotting Add_Delete 869 to Nora's 145 spec model

fig = plt.figure()


#add in NIST model

volfrac_of_btp = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
# fracs = [x*100 for x in volfrac_of_btp]
flamespeeds = [0.40875258644125273,0.16966926524557838,0.09506093355318838,0.07327356686247803,0.061265194613989125,0.052793644460558425,0.04667136814266926,0.04106928680179994,0.0365547487209216,0.03252991701877541]
speeds_ = [x*100 for x in flamespeeds]


add_del_fractions= [0.0, 0.0034246488829682868, 0.006825921381900819, 0.01020405603073009, 0.01355928812903828, 0.016891849796691408, 0.02020197002736977, 0.023489874741020596, 0.02675578683525816, 0.029999926235735837]
add_del_spds = [0.36836118323651895,0.3105092939374996,0.26951488651530936,0.2279009010508614,0.18438954969571783,0.14290043159766835,0.10738962623859874,0.08418362589785387,0.06864932292606565,0.05698713190798205]
add_del_speeds = [x*100 for x in add_del_spds]

ax1 = fig.add_subplot(111)

ax1.plot(add_del_fractions, add_del_speeds, '-', c='m', label='Add_Delete, 298K' )
ax1.plot(volfrac_of_btp, speeds_, '-', c='g', label='NIST, 298K' )
ax1.plot(exper_fracs, exper_speeds, '-', c='b', label='NIST, experimental 298K' )
ax1.plot(NIST_fracs, NIST_speeds, '-', c='r', label='NIST model from paper, 298K' )




plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Flame Speeds of Different Model Sizes (120-140)')
ax1.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))

# %% [markdown]
# Plotting Flipping 869 840

# %%
#Plotting Add_Delete 869 840 to Nora's 145 species model

fig = plt.figure()


#add in NIST model

volfrac_of_btp = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
# fracs = [x*100 for x in volfrac_of_btp]
flamespeeds = [0.40875258644125273,0.16966926524557838,0.09506093355318838,0.07327356686247803,0.061265194613989125,0.052793644460558425,0.04667136814266926,0.04106928680179994,0.0365547487209216,0.03252991701877541]
speeds_ = [x*100 for x in flamespeeds]


add_del_fractions= [0.0, 0.0034246488829682868, 0.006825921381900819, 0.01020405603073009, 0.01355928812903828, 0.016891849796691408, 0.02020197002736977, 0.023489874741020596, 0.02675578683525816, 0.029999926235735837]
add_del_spds = [0.36107238778237605,0.24492237086372307,0.1755332467443352,0.1309892554991152,0.10470041196534492,0.08662688202366783,0.07359029647223145,0.06338709300514775,0.05501590012425283, 0.04828751014742509 ]
add_del_speeds = [x*100 for x in add_del_spds]

ax1 = fig.add_subplot(111)  

ax1.plot(add_del_fractions, add_del_speeds, '-', c='m', label='Add_Delete, 298K' )
ax1.plot(volfrac_of_btp, speeds_, '-', c='g', label='NIST, 298K' )
ax1.plot(exper_fracs, exper_speeds, '-', c='b', label='NIST, experimental 298K' )
ax1.plot(NIST_fracs, NIST_speeds, '-', c='r', label='NIST model from paper, 298K' )



plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Flame Speeds of Different Model Sizes (120-140)')
ax1.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))

# %%
#Plotting Add_Delete 869 840 1 to Nora's 145 species model

fig = plt.figure()


#add in NIST model

volfrac_of_btp = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
# fracs = [x*100 for x in volfrac_of_btp]
flamespeeds = [0.40875258644125273,0.16966926524557838,0.09506093355318838,0.07327356686247803,0.061265194613989125,0.052793644460558425,0.04667136814266926,0.04106928680179994,0.0365547487209216,0.03252991701877541]
speeds_ = [x*100 for x in flamespeeds]


add_del_fractions= [0.0, 0.0034246488829682868, 0.006825921381900819]# 0.01020405603073009, 0.01355928812903828, 0.016891849796691408, 0.02020197002736977, 0.023489874741020596, 0.02675578683525816, 0.029999926235735837]
add_del_spds = [0.3432238777890245,0.2285505461342767,0.16258013148454378]#,0.1309892554991152,0.10470041196534492,0.08662688202366783,0.07359029647223145,0.06338709300514775,0.05501590012425283, 0.04828751014742509 ]
add_del_speeds = [x*100 for x in add_del_spds]

ax1 = fig.add_subplot(111)  

ax1.plot(add_del_fractions, add_del_speeds, '-', c='m', label='Add_Delete, 298K' )
ax1.plot(volfrac_of_btp, speeds_, '-', c='g', label='NIST, 298K' )
ax1.plot(exper_fracs, exper_speeds, '-', c='b', label='NIST, experimental 298K' )
ax1.plot(NIST_fracs, NIST_speeds, '-', c='r', label='NIST model from paper, 298K' )




plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Flame Speeds of Different Model Sizes (120-140)')
ax1.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))

# %%
#Plotting Add_Delete 869 840 245 to Nora's 145 species model

fig = plt.figure()


#add in NIST model

volfrac_of_btp = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
# fracs = [x*100 for x in volfrac_of_btp]
flamespeeds = [0.40875258644125273,0.16966926524557838,0.09506093355318838,0.07327356686247803,0.061265194613989125,0.052793644460558425,0.04667136814266926,0.04106928680179994,0.0365547487209216,0.03252991701877541]
speeds_ = [x*100 for x in flamespeeds]


add_del_fractions= [0.0, 0.0034246488829682868, 0.006825921381900819]# 0.01020405603073009, 0.01355928812903828, 0.016891849796691408, 0.02020197002736977, 0.023489874741020596, 0.02675578683525816, 0.029999926235735837]
add_del_spds = [0.3924053995135405,0.26770472000997564,0.19191743162542732]#,0.1309892554991152,0.10470041196534492,0.08662688202366783,0.07359029647223145,0.06338709300514775,0.05501590012425283, 0.04828751014742509 ]
add_del_speeds = [x*100 for x in add_del_spds]

ax1 = fig.add_subplot(111)  

ax1.plot(add_del_fractions, add_del_speeds, '-', c='m', label='Add_Delete, 298K' )
ax1.plot(volfrac_of_btp, speeds_, '-', c='g', label='NIST, 298K' )
ax1.plot(exper_fracs, exper_speeds, '-', c='b', label='NIST, experimental 298K' )
ax1.plot(NIST_fracs, NIST_speeds, '-', c='r', label='NIST model from paper, 298K' )





plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Flame Speeds of Different Model Sizes (120-140)')
ax1.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))

# %%
#Plotting Add_Delete 869 840 245 1 to Nora's 145 species model


#Plotting Add_Delete 869 840 245 to Nora's 145 species model

fig = plt.figure()


#add in NIST model

volfrac_of_btp = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
# fracs = [x*100 for x in volfrac_of_btp]
flamespeeds = [0.40875258644125273,0.16966926524557838,0.09506093355318838,0.07327356686247803,0.061265194613989125,0.052793644460558425,0.04667136814266926,0.04106928680179994,0.0365547487209216,0.03252991701877541]
speeds_ = [x*100 for x in flamespeeds]


add_del_fractions= [0.0, 0.0034246488829682868, 0.006825921381900819]# 0.01020405603073009, 0.01355928812903828, 0.016891849796691408, 0.02020197002736977, 0.023489874741020596, 0.02675578683525816, 0.029999926235735837]
add_del_spds = [0.3755762010568311, 0.2524869184436651, 0.17909772494227935]# 554991152,0.10470041196534492,0.08662688202366783,0.07359029647223145,0.06338709300514775,0.05501590012425283, 0.04828751014742509 ]
add_del_speeds = [x*100 for x in add_del_spds]

ax1 = fig.add_subplot(111)  

ax1.plot(add_del_fractions, add_del_speeds, '-', c='m', label='298K' ) #replaced with NIST reaction('HF <=> H + F', [3.120000e+13, 0.0, 99320.0])
ax1.plot(volfrac_of_btp, speeds_, '-', c='g', label='NIST, 298K' )
ax1.plot(exper_fracs, exper_speeds, '-', c='b', label='NIST, experimental 298K' )
ax1.plot(NIST_fracs, NIST_speeds, '-', c='r', label='NIST model from paper, 298K' )





plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Flame Speeds of Different Model Sizes (120-140)')
ax1.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))

# %%
#Plotting Add_Delete 840 to Nora's 145 species model


fig = plt.figure()


#add in NIST model

volfrac_of_btp = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
# fracs = [x*100 for x in volfrac_of_btp]
flamespeeds = [0.40875258644125273,0.16966926524557838,0.09506093355318838,0.07327356686247803,0.061265194613989125,0.052793644460558425,0.04667136814266926,0.04106928680179994,0.0365547487209216,0.03252991701877541]
speeds_ = [x*100 for x in flamespeeds]


add_del_fractions= [0.0,0.0034246488829682868,0.01355928812903828,0.02675578683525816,0.029999926235735837]
add_del_spds = [0.36107327254607946,0.250555167496699,0.10745362172398058,0.05542823563046761,0.048609489154778474]
add_del_speeds = [x*100 for x in add_del_spds]

ax1 = fig.add_subplot(111)  

ax1.plot(add_del_fractions, add_del_speeds, '-', c='m', label='Add_Delete, 298K' )
ax1.plot(volfrac_of_btp, speeds_, '-', c='g', label='NIST, 298K' )
ax1.plot(exper_fracs, exper_speeds, '-', c='b', label='NIST, experimental 298K' )
ax1.plot(NIST_fracs, NIST_speeds, '-', c='r', label='NIST model from paper, 298K' )




plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Flame Speeds of Different Model Sizes (120-140)')
ax1.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))
  

    #THIS could not calculate the flame speed after the second point :(

# %%
#NIST with 840 substituted in,  CAUTION: this is NIST substituted with RMG's (below)
'''
three_body_reaction('F(37) + H(8) + M <=> HF(38) + M', [1.700000e+21, -2.0, 0.0],
                    efficiencies='C2H6(31):3.0 CF2O(49):5.0 CH2F2(41):6.0 CH4(3):2.0 CHF3(42):6.0 CO(15):1.5 CO2(16):2.0 H2(10):2.0 H2O(5):9.0 HF(38):2.0')

'''

fig = plt.figure()


#add in NIST model

volfrac_of_btp = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
# fracs = [x*100 for x in volfrac_of_btp]
flamespeeds = [0.40875258644125273,0.16966926524557838,0.09506093355318838,0.07327356686247803,0.061265194613989125,0.052793644460558425,0.04667136814266926,0.04106928680179994,0.0365547487209216,0.03252991701877541]
speeds_ = [x*100 for x in flamespeeds]


add_del_fractions= [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
add_del_spds = [0.40261823078473435, 0.3154458381975536, 0.23926780592373698, 0.176873820623797, 0.1274057781817947, 0.09235234588514465, 0.0703702000974629, 0.05671093834662754, 0.04736573153177111, 0.04032483998500029]
add_del_speeds = [x*100 for x in add_del_spds]

add_del_fractions_Nora= [0.0,0.0034246488829682868,0.01355928812903828,0.02675578683525816,0.029999926235735837]
add_del_spds_Nora = [0.36107327254607946,0.250555167496699,0.10745362172398058,0.05542823563046761,0.048609489154778474]
add_del_speeds_Nora = [x*100 for x in add_del_spds_Nora]




ax1 = fig.add_subplot(111)  

ax1.plot(add_del_fractions_Nora, add_del_speeds_Nora, '-', label='Nora with 840 replaced, 298K' ) #replaced with NIST reaction('HF <=> H + F', [3.120000e+13, 0.0, 99320.0])
ax1.plot(add_del_fractions, add_del_speeds, '-', c='m', label='NIST with 840 replaced as P-dependent, 298K' )
ax1.plot(volfrac_of_btp, speeds_, '-', c='g', label='NIST (previously graphed by Nora), 298K' )
ax1.plot(exper_fracs, exper_speeds, '-', c='b', label='NIST, experimental data from figure, 298K' )
ax1.plot(NIST_fracs, NIST_speeds, '-', c='r', label='NIST model data from figure, 298K' )
ax1.plot(Noras_840_June_fracs, Noras_840_June_spds, '-', label='Nora with 840 replaced from June, 298K' )
ax1.plot(pym_gas_copy_840_original_thirdbodyNIST_fracs, pym_gas_copy_840_original_thirdbodyNIST_spds, '-', label='pym_gas_copy_840_original_thirdbodyNIST_' )
ax1.plot(Nora_original_pdep_model_fracs, Nora_original_pdep_model_spds, '-', label='Noras original pdep model' )



plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Flame Speeds of Different Model Sizes (120-140)')
ax1.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))
  

#NIST model breaks by just flipping the kinetics in that one reaction!!!!!

# %%
#FROM web data digitalizer

#experimental data at 298 K 
exper_fracs = [0, 0.5/100, 0.9984326018808776/100, 1.4968652037617554/100, 1.9984326018808776/100]
exper_speeds = [35.97260273972603, 24.575342465753423, 16.246575342465754, 9.890410958904113, 6]

ugly = [0, 38.986301369863014,
0.12068965517241381, 36.08219178082192,
0.22727272727272718, 33.61643835616439,
0.32131661442006265, 31.369863013698634,
0.40282131661442, 29.34246575342466,
0.49686520376175536, 27.095890410958905,
0.5721003134796236, 25.616438356164387,
0.6818181818181817, 23.424657534246577,
0.7821316614420062, 21.5068493150685,
0.891849529780564, 19.47945205479452,
0.9984326018808776, 17.561643835616444,
1.1520376175548586, 15.150684931506852,
1.3087774294670846, 12.958904109589042,
1.4811912225705324, 10.93150684931507,
1.6567398119122256, 9.287671232876711,
1.8197492163009403, 8.027397260273979,
1.9984326018808776, 6.986301369863014,
2.1959247648902815, 6,
2.384012539184953, 5.397260273972606,
2.606583072100313, 4.794520547945204,
2.813479623824451, 4.410958904109592,
2.998432601880878, 3.972602739726028]

# %%
NIST_fracs = []
NIST_speeds = []


for id, val in enumerate(ugly):
    if id % 2 == 0:
        NIST_fracs.append(val/100)
    else: 
        NIST_speeds.append(val)

# %%
# this is Nora's model, with 840 in RMG replaced with the original 840 from original June file 

Noras_840_June_fracs = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
Noras_840_June_spds_ =[0.36109838478736733,0.3105428996273911,0.2685780834695869,0.2281146906071974,0.18429358939685636,0.1422699076111181,0.1075269023812445,0.08395829741693628,0.0684163102547213,0.05717442553197118]
Noras_840_June_spds = [x*100 for x in Noras_840_June_spds_]

pym_gas_copy_840_original_thirdbodyNIST_fracs = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
pym_gas_copy_840_original_thirdbodyNIST_spds_=[0.4026814527159335,0.3154485525826302,0.23928736439292117,0.17685934477572474,0.12740820813212178,0.09237412657478043,0.0703705362462705,0.0567110863416496,0.04736280223272425,0.04032484512277838]
pym_gas_copy_840_original_thirdbodyNIST_spds = [x*100 for x in pym_gas_copy_840_original_thirdbodyNIST_spds_]

Nora_original_pdep_model_fracs = [0.0, 0.0034246488829682868, 0.006825921381900819, 0.01020405603073009, 0.01355928812903828, 0.016891849796691408, 0.02020197002736977, 0.023489874741020596, 0.02675578683525816, 0.029999926235735837]
Nora_original_pdep_model_spds_=[0.368361183236519, 0.3105076283048821, 0.2695128172909165, 0.2278994661302301, 0.1843891692549333, 0.1429087785778964, 0.10739053748308904, 0.0841843877033093, 0.06864993995452552, 0.0569876952658005]
Nora_original_pdep_model_spds = [x*100 for x in Nora_original_pdep_model_spds_]

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)  

ax1.plot(add_del_fractions_Nora, add_del_speeds_Nora, '-', label='RMG with 840 replaced, not pdep' ) #replaced with NIST reaction('HF <=> H + F', [3.120000e+13, 0.0, 99320.0])
ax1.plot(add_del_fractions, add_del_speeds, '-', c='m', label='NIST with 840 replaced as pdep from June file, ORIGINAL' ) # pym_gas_copy_840_original_thirdbodyNIST_
ax1.plot(volfrac_of_btp, speeds_, '-', label='NIST (previously graphed by Nora), false' )
ax1.plot(exper_fracs, exper_speeds, '-', c='b', label='NIST, experimental data from figure' )
ax1.plot(NIST_fracs, NIST_speeds, '-', c='r', label='NIST, model data from figure' )
ax1.plot(Noras_840_June_fracs, Noras_840_June_spds, '-', label='RMG with 840 replaced as pdep from June file' ) #replaced with three_body_reaction('F + H + M <=> HF + M', [3.120000e+13, 0.0, 99320.0])
ax1.plot(Nora_original_pdep_model_fracs, Nora_original_pdep_model_spds,'-', c='g', label='RMG original pdep model' )



plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Flame Speeds of Different Model Sizes (120-140)')
ax1.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))
  

#NIST model breaks by just flipping the kinetics in that one reaction!!!!!

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)  

#David's model found on scratch (297 species)

volfrac_of_btp_davids = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
#fracs = [x*100 for x in volfrac_of_btp]
flamespeeds_davids =[0.37136450673384547,0.3207513341286498,0.2818713801086439,0.23748473936855224,0.186777736426303,0.13939214207026443,0.10422234607579989,0.08253213292529699,0.06852677905059192,0.05798758981932021]
spds_davids = [x*100 for x in flamespeeds_davids]

#ax1.plot(add_del_fractions_Nora, add_del_speeds_Nora, '-', label='1') #'RMG with 840 replaced, not pdep' ) #replaced with NIST reaction('HF <=> H + F', [3.120000e+13, 0.0, 99320.0]) #not credible, can't just change rates like this is I took out +M 
ax1.plot(add_del_fractions, add_del_speeds, '-', c='m', label='1') #'NIST with 840 replaced as pdep from June file, ORIGINAL' ) # pym_gas_copy_840_original_thirdbodyNIST_
ax1.plot(volfrac_of_btp, speeds_, '-', label='2') #'NIST (previously graphed by Nora), false' )
ax1.plot(exper_fracs, exper_speeds, '-', c='b', label='3') #'NIST, experimental data from figure' )
ax1.plot(NIST_fracs, NIST_speeds, '-', c='r', label='4') #'NIST, model data from figure' )
ax1.plot(Noras_840_June_fracs, Noras_840_June_spds, '-', label='5') #'RMG with 840 replaced as pdep from June file' ) #replaced with three_body_reaction('F + H + M <=> HF + M', [3.120000e+13, 0.0, 99320.0])
ax1.plot(Nora_original_pdep_model_fracs, Nora_original_pdep_model_spds,'-', c='g', label='6') #'RMG original pdep model' )
ax1.plot(volfrac_of_btp_davids, spds_davids,'-', label='7 davids pdep') #'RMG original pdep model' )



plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Flame Speeds of Different Model Sizes')
ax1.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))
  

#NIST model breaks by just flipping the kinetics in that one reaction!!!!!
