# %%
import numpy as np
import matplotlib.pylab as plt

# %% [markdown]
# # Recreating the NIST model

# %% [markdown]
# ## With FFCM Seed

# %% [markdown]
#  David's 2_BTP model with FFCM and pdep

# %%
#David's model found on scratch (297 species)

volfrac_of_btp = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
#fracs = [x*100 for x in volfrac_of_btp]
flamespeeds =[0.37136450673384547,0.3207513341286498,0.2818713801086439,0.23748473936855224,0.186777736426303,0.13939214207026443,0.10422234607579989,0.08253213292529699,0.06852677905059192,0.05798758981932021]
speeds = [x*100 for x in flamespeeds]


fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.plot(volfrac_of_btp, speeds, '-', c='green', label='Methane-Air, T = 298 K, phi = 1' )

plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Methane-Air mix | 2-BTP | mech = RMG (DF)')
plt.legend()

for xy in zip(volfrac_of_btp, speeds):
   plt.annotate('%.2f' % xy[1], xy=xy)

# %%
#David's model found on scratch (130 sp)

volfrac_of_btp = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
#fracs = [x*100 for x in volfrac_of_btp]
flamespeeds =[0.3713641703913062, 0.31309699912753264, 0.27062189457372104, 0.22470106831605768, 0.17864650974778057, 0.1324862072599867, 0.09706638066306723, 0.07618601555922339, 0.06233075466910072, 0.05191335712547286]
speeds = [x*100 for x in flamespeeds]


fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.plot(volfrac_of_btp, speeds, '-', c='green', label='Methane-Air, T = 298 K, phi = 1' )

plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Methane-Air mix | 2-BTP | mech = RMG (DF)')
plt.legend()

for xy in zip(volfrac_of_btp, speeds):
   plt.annotate('%.2f' % xy[1], xy=xy)



#Below is David's model calculated USING HIS OWN PLOTTING/FLAMESPEED SCRIPT
spds = [37.43398569007991, 34.00499476217264, 30.941665969223152, 27.99922939195401, 24.75799021864515, 17.00683089655361, 10.996771514717754, 7.740170339324867, 5.977598855675177, 4.831664829020242, 4.026237282864925, 3.4245443803538187, 2.9448314296865647]
fracs = [0.0, 0.0025, 0.005, 0.0075, 0.01, 0.015, 0.02, 0.025, 0.03, 0.035, 0.04, 0.045, 0.05]

ax1.plot(fracs, spds, '-', c='r', label='David')


###########these calcs come from david's "flame_speeds_refined.csv" so maybe that's why its not exact? ###########

# %%
#David's model found on scratch (92 and 93 species)

volfrac_of_btp_92 = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
#fracs = [x*100 for x in volfrac_of_btp]
flamespeeds_92 =[0.37109205720733224,0.30525318390280876,0.25481927200253296,0.21101296267422096,0.16862186152102246,0.1278575872124486,0.08822013457947865,0.060941762916593714,0.042281608818560655,0.03131214353151918]
speeds_92 = [x*100 for x in flamespeeds_92]


volfrac_of_btp_93 = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
#fracs = [x*100 for x in volfrac_of_btp]
flamespeeds_93 =[0.37106322079154475,0.27973967960343715,0.08062050086551531,0.038718129454414094,0.028883816547950476,0.022900502524479928,0.018825433394238648,0.015681574279519248,0.013267951885006775,0.011279999540863728]
speeds_93 = [x*100 for x in flamespeeds_93]



fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.plot(volfrac_of_btp_92, speeds_92, '-', c='green', label='92 species' )
ax1.plot(volfrac_of_btp_93, speeds_93, '-', c='green', label='93 species' )

plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Methane-Air mix | 2-BTP | mech = RMG (DF)')
plt.legend()

for xy in zip(volfrac_of_btp_92, speeds_92):
    plt.annotate('%.2f' % xy[1], xy=xy)

# %% [markdown]
# Nora's 2_BTP model with FFCM Seed

# %%
#Nora's 2_BTP model with FFCM seed (130 species)

volfrac_of_btp = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
#fracs = [x*100 for x in volfrac_of_btp]
flamespeeds =[0.3685121120941343,0.28667917723811454,0.1581411723275068,0.058981028846433504,0.044807992111318216,0.03782237367947444,0.03312213228662398,0.02937453570826892,0.026332824456640074,0.023825383032073086]
speeds = [x*100 for x in flamespeeds]


fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.plot(volfrac_of_btp, speeds, '-', c='green', label='Methane-Air, T = 298 K, phi = 1' )

plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Methane-Air mix | 2-BTP | mech = RMG (NK with seed)')
plt.legend()

for xy in zip(volfrac_of_btp, speeds):
   plt.annotate('%.2f' % xy[1], xy=xy)

# %%
#what if i model one with even fewer species???
#Nora's 2_BTP model with FFCM seed (120 species)


volfrac_of_btp = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
#fracs = [x*100 for x in volfrac_of_btp]
flamespeeds =[0.3685322972205421,0.3102357469174988,0.27123110327430205,0.23287866477924904,0.19121877417451943,0.1521093322355705,0.1168702422587303,0.09048738577966106,0.07409831974446675,0.06252325260258176]
speeds = [x*100 for x in flamespeeds]


fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.plot(volfrac_of_btp, speeds, '-', c='green', label='Methane-Air, T = 298 K, phi = 1' )

plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Methane-Air mix | 2-BTP | mech = RMG (NK with seed)')
plt.legend()

for xy in zip(volfrac_of_btp, speeds):
   plt.annotate('%.2f' % xy[1], xy=xy)

# %%
#Nora's 2_BTP model with FFCM seed (140 species)

volfrac_of_btp = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
#fracs = [x*100 for x in volfrac_of_btp]
flamespeeds =[0.36834864251665933,0.310672199084563,0.2698396551525493,0.22822441079109979,0.1844318230553318,0.14267542118065035,0.10742161658496129,0.08443298512689705,0.06900043266669485,0.057231958587147864]
speeds = [x*100 for x in flamespeeds]


fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.plot(volfrac_of_btp, speeds, '-', c='green', label='Methane-Air, T = 298 K, phi = 1' )

plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Methane-Air mix | 2-BTP | mech = RMG (NK with seed)')
plt.legend()

for xy in zip(volfrac_of_btp, speeds):
   plt.annotate('%.2f' % xy[1], xy=xy)

# %%
#Nora's 2_BTP model with largest size (145 species)

volfrac_of_btp = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
#fracs = [x*100 for x in volfrac_of_btp]
flamespeeds =[0.36836118323651834,0.31050762830488216,0.2695128172909165,0.22789946613022974,0.18438916925493348,0.1429087785778958,0.10739053748308872,0.08418438770424427,0.0686499399546852,0.05698769585957772]
speeds = [x*100 for x in flamespeeds]


fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.plot(volfrac_of_btp, speeds, '-', c='green', label='Methane-Air, T = 298 K, phi = 1' )

plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Methane-Air mix | 2-BTP | mech = RMG (NK, 145 species)')
plt.legend()

for xy in zip(volfrac_of_btp, speeds):
   plt.annotate('%.2f' % xy[1], xy=xy)

# %% [markdown]
# Nora's 2_BTP model, using BurkeH2O2inN2 rxn library and FFCM seed

# %%
#Nora's 2_BTP model, using BurkeH2O2inN2 rxn library and FFCM seed 
volfrac_of_btp = [0.0, 0.0034246488829682868, 0.006825921381900819, 0.01020405603073009, 0.01355928812903828, 0.016891849796691408, 0.02020197002736977, 0.023489874741020596, 0.02675578683525816, 0.029999926235735837]
flamespeeds = [0.3576115846818522, 0.30677131027545157, 0.26999779535909413, 0.2317713760064634, 0.19343349570120777, 0.1550158738371358, 0.122001710784021, 0.09493682243696915, 0.0773475853379356, 0.06461212490398795]
speeds = [x*100 for x in flamespeeds]


fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.plot(volfrac_of_btp, speeds, '-', c='green', label='Methane-Air, T = 298 K, phi = 1' )

plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Methane-Air mix | 2-BTP | mech = RMG (with new rxn library)')
plt.legend()

for xy in zip(volfrac_of_btp, speeds):
   plt.annotate('%.2f' % xy[1], xy=xy)

# %%
#Nora's 2_BTP model, using BurkeH2O2inN2 rxn library and FFCM seed (150 sp)
volfrac_of_btp = [0.0, 0.0034246488829682868, 0.006825921381900819, 0.01020405603073009, 0.01355928812903828, 0.016891849796691408, 0.02020197002736977, 0.023489874741020596, 0.02675578683525816, 0.029999926235735837]
flamespeeds = [0.35726437882314316,0.30635969260245743,0.2690592838593731,0.2281080982838678,0.18550982776736233,0.14132626885664715,0.10145750542848044,0.07642034238383505,0.05879651781527725,0.047356185820809506]
speeds = [x*100 for x in flamespeeds]


fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.plot(volfrac_of_btp, speeds, '-', c='green', label='Methane-Air, T = 298 K, phi = 1' )

plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Methane-Air mix | 2-BTP | mech = RMG (with new rxn library)')
plt.legend()

for xy in zip(volfrac_of_btp, speeds):
   plt.annotate('%.2f' % xy[1], xy=xy)

# %% [markdown]
# As my core size increases from 120 to 140, there are reactions added that made flamespeed pretty good, but then additional reactions that screwed it up again. Let's analyze that range.

# %% [markdown]
# ## Without FFCM Seed

# %%
#Nora's 2_BTP model

volfrac_of_btp = [0.0, 0.0034246488829682868, 0.006825921381900819, 0.01020405603073009, 0.01355928812903828, 0.016891849796691408, 0.02020197002736977, 0.023489874741020596, 0.02675578683525816, 0.029999926235735837]
#fracs = [x*100 for x in volfrac_of_btp]
flamespeeds =[0.03508608131328457, 0.010210954392723754, 0.006464637833426167, 0.005426300588725869, 0.004923045329588489, 0.004594396143536239, 0.004321670260990777, 0.004106011390029532, 0.003914517982285885, 0.003753248591039618]
speeds = [x*100 for x in flamespeeds]


fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.plot(volfrac_of_btp, speeds, '-', c='green', label='Methane-Air, T = 298 K, phi = 1' )

plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Methane-Air mix | 2-BTP | mech = RMG (NK)')
plt.legend()

for xy in zip(volfrac_of_btp, speeds):
   plt.annotate('%.2f' % xy[1], xy=xy)
