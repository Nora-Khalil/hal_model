# %%
import cantera as ct 
import numpy as np
import matplotlib.pylab as plt

# %%
#NIST model

volfrac_of_btp = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
# fracs = [x*100 for x in volfrac_of_btp]
flamespeeds = [0.40875258644125273,0.16966926524557838,0.09506093355318838,0.07327356686247803,0.061265194613989125,0.052793644460558425,0.04667136814266926,0.04106928680179994,0.0365547487209216,0.03252991701877541]
speeds = [x*100 for x in flamespeeds]


fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.plot(volfrac_of_btp, speeds, '-', c='green', label='Methane-Air, T = 298 K, phi = 1' )

plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Methane-Air mix | 2-BTP | mech = NIST')
plt.legend()

# %%
#David's RMG model

# for equivalence ratio = 1 (0.095 vol frac of methane), speed = 24.8722 m/s


volfrac_of_btp = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
# fracs = [x*100 for x in volfrac_of_btp]
flamespeeds = [0.24914343607086475,0.08264357888575126,0.06642514374789703,0.05841990045266166,0.05232430718166388,0.047049309242108144,0.04224911349801363,0.038222120278756024,0.03464720141220705,0.031409762769288564]
speeds = [x*100 for x in flamespeeds]

fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.plot(volfrac_of_btp, speeds, '-', c='green', label='Methane-Air, T = 298 K, phi = 1' )

plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Methane-Air mix | 2-BTP | mech = RMG')
plt.legend()
