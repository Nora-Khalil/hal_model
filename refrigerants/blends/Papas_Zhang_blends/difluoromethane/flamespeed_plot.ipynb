# %% [markdown]
# MODEL GENERATION COMPLETED
#
# The final model core has 63 species and 694 reactions
# The final model edge has 2724 species and 6714 reactions

# %%
import matplotlib.pylab as plt
import numpy as np
# %matplotlib inline

# %%
#Figure 2 of Papas 

data = [0.6, 3.321428571428572,
0.6477876106194689, 4,
0.686725663716814, 4.5476190476190474,
0.7256637168141593, 5.035714285714286,
0.7752212389380531, 5.666666666666666,
0.7999999999999998, 5.9523809523809526,
0.902654867256637, 6.7023809523809526,
0.950442477876106, 6.869047619047619,
0.9999999999999998, 6.857142857142857,
1.0530973451327432, 6.773809523809524,
1.1522123893805307, 6.2142857142857135,
1.2106194690265486, 5.69047619047619,
1.2654867256637166, 5.154761904761905,
1.31858407079646, 4.619047619047619,
1.3628318584070795, 4.178571428571429,
1.4, 3.821428571428572]

Papas_phis = []
Papas_speeds = []
for x in list(range(len(data))):
    if x%2==0:
        Papas_phis.append(data[x])
    else: 
        Papas_speeds.append(data[x])

# %%
#data for difluoromethane
phis = [0.4, 0.4827586206896552, 0.5241379310344828, 0.5655172413793104, 0.6482758620689656, 0.7310344827586208, 0.7724137931034484, 0.8137931034482759, 0.8551724137931036, 0.8965517241379312, 0.9379310344827587, 0.9793103448275863, 1.020689655172414, 1.0620689655172415, 1.103448275862069, 1.1448275862068966, 1.1862068965517243, 1.227586206896552, 1.2689655172413796, 1.310344827586207, 1.3517241379310345, 1.3931034482758622, 1.4344827586206899, 1.4758620689655175, 1.5172413793103452, 1.5586206896551724, 1.6]
speeds = np.array([0.0037681699622848534, 0.008872611358313194, 0.012712865073363258, 0.017794067448184712, 0.030515062264068946, 0.04592604264559624, 0.05401815132920128, 0.06029617526279927, 0.06620414710133933, 0.07063572222005558, 0.07363101983742808, 0.07513871506630403, 0.07534829972784167, 0.0741287823718414, 0.072025667194897, 0.06882644624821621, 0.06495046515913869, 0.06064601057863507, 0.056049202268005735, 0.0514352563188021, 0.046898553015092735, 0.04265850525833517, 0.03871475785743218, 0.035143972532464145, 0.03207615830695433, 0.02944831842679974, 0.027209857566558925])*100


#plotting
fig = plt.figure()
ax1 = fig.add_subplot(111) 

ax1.plot(phis, speeds, '-', c='g', label='RMG model' )
ax1.plot(Papas_phis, Papas_speeds, '-', c='black', label='Papas' )


plt.xlabel('Equivalence Ratio')
plt.ylabel('Su (cm/s)')
plt.title('Flame Speeds of Difluoromethane at Increasing Equiv. Ratio')
ax1.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))
