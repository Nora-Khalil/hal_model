# %% [markdown]
# MODEL GENERATION COMPLETED
#
# Final model not made yet. This model has 201 species.

# %%
import matplotlib.pylab as plt
import numpy as np
import os 
import re
import pandas as pd
# %matplotlib inline

# %%
dictionary_of_data = {}

list_of_blends = os.listdir('/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/Papas_Zhang_blends/rmg_built_blends_with_species_in_core/2,3,3,3-tetrafluoropropene_difluoromethane/data/')
for file in list_of_blends[1:]:
    df = pd.read_csv(f'/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/Papas_Zhang_blends/rmg_built_blends_with_species_in_core/2,3,3,3-tetrafluoropropene_difluoromethane/data/{file}')
    speed = df['velocity'][0]
    match = re.match('(\S+)\.csv',file)
    fraction = float(match.group(1))
    dictionary_of_data[fraction] = speed

# %%
#data for blend

fractions = [x for x in dictionary_of_data.keys()]
calculated_speeds = np.array([x for x in dictionary_of_data.values()])

# %%
calculated_speeds
# Out:
# array([0.04148716, 0.03913259, 0.03770056, 0.03679618, 0.03589035,
#        0.03532778, 0.03491551, 0.03463704, 0.03445124, 0.03431511,
#        0.03422858, 0.03412986, 0.03416122, 0.03415201, 0.03426556,
#        0.03433137, 0.03443382, 0.03451751, 0.03453608, 0.03468204,
#        0.0348288 , 0.03512895, 0.03535075, 0.03556431, 0.03582781])

# %%
experimental Papas, Zhang. plot experimental!

# %%
#209 species 
_209_fracs=[0.0, 0.041666666666666664, 0.08333333333333333, 0.125, 0.16666666666666666, 0.20833333333333331, 0.25, 0.29166666666666663, 0.3333333333333333, 0.375, 0.41666666666666663, 0.4583333333333333, 0.5, 0.5416666666666666, 0.5833333333333333, 0.625, 0.6666666666666666, 0.7083333333333333, 0.75, 0.7916666666666666, 0.8333333333333333, 0.875, 0.9166666666666666, 0.9583333333333333, 1.0]
_209_species=np.array([0.04148716119956937, 0.03913259013159586, 0.03770056480590172, 0.036796184538311544, 0.035890346917295396, 0.035327780487677284, 0.03491550509322894, 0.034637041432382595, 0.034451239447863484, 0.03431510936435537, 0.03422858353607885, 0.03412986366616172, 0.03416121734988276, 0.03415200988471959, 0.0342655633691885, 0.03433137404297832, 0.03443382031099323, 0.034517511753118346, 0.034536075510374215, 0.03468203791828322, 0.03482880103575237, 0.03512895117795561, 0.03535075249296809, 0.03556430645766131, 0.03582781062923099])

# %%
#plotting
fig = plt.figure()
ax1 = fig.add_subplot(111) 

ax1.plot(fractions, calculated_speeds*100, '-', c='g', label='RMG model' )
ax1.plot(_209_fracs, _209_species*100, '-', c='black', label='Papas' )

listOf_Yticks = np.arange(0, 12, 2)
plt.yticks(listOf_Yticks)

plt.xlabel('Equivalence Ratio')
plt.ylabel('Su (cm/s)')
plt.title('Flame Speeds of Propane at Increasing Equiv. Ratio')
ax1.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))

# %%
#redone

# %%
dictionary_of_data = {}

list_of_blends = os.listdir('/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/Papas_Zhang_blends/propane/data/phis')
for file in list_of_blends[1:]:
    df = pd.read_csv(f'/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/Papas_Zhang_blends/propane/data/phis/{file}')
    speed = df['velocity'][0]
    match = re.match('(\S+)\.csv',file)
    fraction = float(match.group(1))
    phi = (24.8)*(fraction/(fraction+1+3.76))
    dictionary_of_data[phi] = speed

# %%
#data for propane

calculated_phis = [x for x in dictionary_of_data.keys()]
calculated_speeds = np.array([x for x in dictionary_of_data.values()])

# %%
#plotting
fig = plt.figure()
ax1 = fig.add_subplot(111) 

ax1.plot(calculated_phis, calculated_speeds*100, '-', c='g', label='RMG model' )
# ax1.plot(calculated_fractions, Papas_speeds, '-', c='black', label='Papas' )

plt.xlabel('Equivalence Ratio')
plt.ylabel('Su (cm/s)')
plt.title('Flame Speeds of Propane at Increasing Equiv. Ratio')
ax1.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))
