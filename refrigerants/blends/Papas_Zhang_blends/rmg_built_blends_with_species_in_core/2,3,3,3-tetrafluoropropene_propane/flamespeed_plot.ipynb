# %% [markdown]
# MODEL GENERATION COMPLETED
#
# Final model not made yet. This model has 259 species.

# %%
import matplotlib.pylab as plt
import numpy as np
import os 
import re
import pandas as pd
# %matplotlib inline

# %%
dictionary_of_data = {}

list_of_blends = os.listdir('/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/Papas_Zhang_blends/rmg_built_blends_with_species_in_core/2,3,3,3-tetrafluoropropene_propane/data/')
for file in list_of_blends[1:]:
    df = pd.read_csv(f'/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/Papas_Zhang_blends/rmg_built_blends_with_species_in_core/2,3,3,3-tetrafluoropropene_propane/data/{file}')
    speed = df['velocity'][0]
    match = re.match('(\S+)\.csv',file)
    fraction = float(match.group(1))
    dictionary_of_data[fraction] = speed

# %%
#data for propane

fractions = [x for x in dictionary_of_data.keys()]
calculated_speeds = np.array([x for x in dictionary_of_data.values()])

# %%
#concatenated

conc_fractions = [0.0,0.041666666666666664,0.08333333333333333,0.125,0.16666666666666666,0.20833333333333331,0.25,0.29166666666666663,0.3333333333333333,0.375,0.41666666666666663,0.4583333333333333,0.5,0.5416666666666666,0.5833333333333333,0.625,0.6666666666666666,0.7083333333333333,0.75,0.7916666666666666,0.8333333333333333,0.875,0.9166666666666666,0.9583333333333333,1.0]
conc_speeds = np.array([0.41746168425980656,0.3972216958761189,0.37699129118011687,0.35637273012932996,0.33572764881745104,0.31602070281560496,0.2956809858374383,0.2757994059710474,0.2576423874810419,0.23839611753263001,0.22191191478483993,0.20496649420484397,0.19008249930711127,0.17705254030796233,0.16468831519016142,0.1536211292200644,0.14344374562815296,0.13440333335970425,0.12457624573688503,0.11656157868519618,0.10861684772984392,0.10049340282271398,0.09312220205721569,0.08489081505136516,0.07680871755888631])

# %%
fractions
# Out:
# [0.0,
#  0.041666666666666664,
#  0.08333333333333333,
#  0.125,
#  0.16666666666666666,
#  0.20833333333333331,
#  0.25,
#  0.29166666666666663,
#  0.3333333333333333,
#  0.375,
#  0.41666666666666663,
#  0.4583333333333333,
#  0.5,
#  0.5416666666666666,
#  0.5833333333333333,
#  0.625,
#  0.6666666666666666,
#  0.7083333333333333,
#  0.75,
#  0.7916666666666666,
#  0.8333333333333333,
#  0.875,
#  0.9166666666666666,
#  0.9583333333333333,
#  1.0]

# %%
calculated_speeds
# Out:
# array([0.35394947, 0.33419856, 0.3100716 , 0.28882958, 0.26726434,
#        0.24611821, 0.22362324, 0.20479843, 0.18767979, 0.17120408,
#        0.15579825, 0.1410279 , 0.12851338, 0.11690963, 0.10562677,
#        0.09623334, 0.08819903, 0.08112986, 0.07516694, 0.07014011,
#        0.06593628, 0.06227262, 0.05959277, 0.05709261, 0.05473375])

# %%
experimental Papas, Zhang. plot experimental!

# %%
#plotting
fig = plt.figure()
ax1 = fig.add_subplot(111) 

ax1.plot(fractions, calculated_speeds*100, '-', c='g', label='RMG-built model' )
# ax1.plot(calculated_fractions, Papas_speeds, '-', c='black', label='Papas' )
ax1.plot(0, 100*calculated_speeds[0], '*', markersize=12 )
ax1.text(0.02,calculated_speeds[0] *100, "35.3 m/s", ha="left")
ax1.plot(1, 100*calculated_speeds[-1], '*', markersize=12 )
ax1.text(.89,(calculated_speeds[-1] *100)-3, "5.47 cm/s", ha="left")
ax1.plot(conc_fractions, conc_speeds*100, '--', c='black',label='concatenated')
ax1.text(.89,(conc_speeds[-1] *100)+2, "7.68 cm/s", ha="left")
ax1.plot(1, 100*conc_speeds[-1], '*', c="black",markersize=12 )
ax1.text(0.05,(conc_speeds[0] *100)-1, "41.6 cm/s", ha="left")
ax1.plot(0, 100*conc_speeds[0], '*', c="black",markersize=12 )



listOf_Yticks = np.arange(0, 45, 5)
plt.yticks(listOf_Yticks)

plt.xlabel(r'$CH_{2}=CFCF_{3}$ Mole Fraction')
plt.ylabel('Su (cm/s)')
plt.title('Flame Speeds of 2,3,3,3-tetrafluoropropene/propane')
ax1.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))

# %%
#redone

# %%
dictionary_of_data = {}

list_of_blends = os.listdir('/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/Papas_Zhang_blends/propane/data/phis')
for file in list_of_blends[1:]:
    df = pd.read_csv(f'/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/Papas_Zhang_blends/propane/data/phis/{file}')
    speed = df['velocity'][0]
    match = re.match('(\S+)\.csv',file)
    fraction = float(match.group(1))
    phi = (24.8)*(fraction/(fraction+1+3.76))
    dictionary_of_data[phi] = speed

# %%
#data for propane

calculated_phis = [x for x in dictionary_of_data.keys()]
calculated_speeds = np.array([x for x in dictionary_of_data.values()])

# %%
#plotting
fig = plt.figure()
ax1 = fig.add_subplot(111) 

ax1.plot(calculated_phis, calculated_speeds*100, '-', c='g', label='RMG model' )
# ax1.plot(calculated_fractions, Papas_speeds, '-', c='black', label='Papas' )

plt.xlabel('Equivalence Ratio')
plt.ylabel('Su (cm/s)')
plt.title('Flame Speeds of Propane at Increasing Equiv. Ratio')
ax1.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))
