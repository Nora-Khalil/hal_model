# %%
import numpy as np
import matplotlib.pylab as plt
import matplotlib
import os 
import re
import pandas as pd
# %matplotlib inline
from matplotlib.lines import Line2D

# %%
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 12}

matplotlib.rc('font', **font)
matplotlib.rc('lines', linewidth=1.8, color='black')

fontdict={'family' : 'normal',
        'weight' : 'bold',
        'size'   : 12}

# %%
# concatenated v. RMG-built 2,3,3,3-tetrafluoropropene_difluoromethane

tetra_mole_fractions = [0.0,
 0.041666666666666664,
 0.08333333333333333,
 0.125,
 0.16666666666666666,
 0.20833333333333331,
 0.25,
 0.29166666666666663,
 0.3333333333333333,
 0.375,
 0.41666666666666663,
 0.4583333333333333,
 0.5,
 0.5416666666666666,
 0.5833333333333333,
 0.625,
 0.6666666666666666,
 0.7083333333333333,
 0.75,
 0.7916666666666666,
 0.8333333333333333,
 0.875,
 0.9166666666666666,
 0.9583333333333333,
 1.0]

#RMG-built 201 species has 201 species and 2911 reactions
RMG_built_201_species_in_core_ = np.array([0.04349124, 0.04202563, 0.04090077, 0.03999785, 0.03932333,
       0.03882904, 0.03837287, 0.03797284, 0.03772854, 0.03747759,
       0.03726866, 0.03714647, 0.03698187, 0.03683237, 0.03670144,
       0.03654695, 0.03644673, 0.03636057, 0.03629533, 0.03625822,
       0.03623524, 0.03622017, 0.03630645, 0.03638878, 0.0365055 ])

#RMG_built_not_in_core
RMG_built_not_in_core_y=np.array([0.08122939, 0.06935301, 0.06077268, 0.05315471, 0.04811685,
       0.04440771, 0.0423281 , 0.04042623, 0.03915587, 0.03827818,
       0.03771683, 0.03739139, 0.03724487, 0.03724317, 0.03733151,
       0.03748353, 0.03721161, 0.0374073 , 0.03759453, 0.03774094,
       0.0378491 , 0.03792412, 0.03851314, 0.03863969, 0.03898441])

RMG_built_not_in_core_x=[0.0,
 0.041666666666666664,
 0.08333333333333333,
 0.125,
 0.16666666666666666,
 0.20833333333333331,
 0.25,
 0.29166666666666663,
 0.3333333333333333,
 0.375,
 0.41666666666666663,
 0.4583333333333333,
 0.5,
 0.5416666666666666,
 0.5833333333333333,
 0.625,
 0.6666666666666666,
 0.7083333333333333,
 0.75,
 0.7916666666666666,
 0.8333333333333333,
 0.875,
 0.9166666666666666,
 0.9583333333333333,
 1.0]




# concatenated blend has 
conc_blend = np.array([0.08112628, 0.07899655, 0.07930432, 0.07987974, 0.0802516 ,
       0.08050796, 0.08064448, 0.08058279, 0.08039065, 0.08013631,
       0.07975911, 0.07943976, 0.07907499, 0.07858927, 0.0780854 ,
       0.07751678, 0.07702838, 0.07644032, 0.07615884, 0.07572419,
       0.07524457, 0.07488486, 0.07435984, 0.07393639, 0.07361851])



#experimental

empty_boxes_x = [0.09955947136563881,0.2,0.30044052863436127,0]
empty_boxes_y=[4.829218317795309,3.7749206023972963,2.813646142813237,6.651060342178055]

filled_diamond_x= [0.2925110132158591,0.4973568281938326]
filled_diamond_y= [2.2793771130007165, 1.7518696854830438]


filled_circle_x=[0.48149779735682824,0.6969162995594715,0.9995594713656388,0.9982378854625553]
filled_circle_y=[1.7996106956254465,1.4108185636717536,1.131543899190655,1.480483557012601]


#plotting
fig = plt.figure()
ax1 = fig.add_subplot(111) 

#ax1.plot(tetra_mole_fractions, RMG_built_201_species_in_core_*100, '-', c='black', label='RMG-built' )
ax1.plot(RMG_built_not_in_core_x, RMG_built_not_in_core_y*100, '-', c='black', label='RMG-built' )
ax1.plot(tetra_mole_fractions, conc_blend*100, '--', c='black', label='concatenated' )
ax1.plot(empty_boxes_x, empty_boxes_y, '*', c='black', markersize=12 )
ax1.plot(filled_diamond_x, filled_diamond_y, 'o', c='black', markersize=10 )
ax1.plot(filled_circle_x, filled_circle_y, 'x', c='black', markersize=10 )
# ax1.plot(1, 100*0.07361851, '*', markersize=12 ) #all difluoro
# ax1.text(1,0.07361851 *100, "7.36 cm/s", ha="left")
# ax1.plot(0, 100*conc_blend[0], '*', markersize=12 ) #all tetra 
# ax1.text(0,(conc_blend[1] *100)+1, "8.11 cm/s", ha="left")




listOf_Yticks = np.arange(0, 12, 2)
plt.yticks(listOf_Yticks)

plt.xlabel(r'$CH_{2}=CFCF_{3}$ Mole Fraction', fontdict=fontdict)
plt.ylabel(r'$S_{L}$ (cm/s)',fontdict=fontdict)
plt.title('2,3,3,3-tetrafluoropropene / difluoromethane', fontsize = 12, fontweight='bold')

legend_elements = [Line2D([0], [0],linestyle='-', color='black', lw=2, label='RMG-built'),
                   Line2D([0], [0], linestyle='--', color='black', label='concatenated'),
                   Line2D([0], [0], marker='*', markersize = 10, linestyle='None', color='black', label='exp. [9]'),                  
                   Line2D([0], [0], marker='o', markersize = 10, linestyle='None', color='black', label='exp. [18]'),                  
                   Line2D([0], [0], marker='x', markersize = 10, linestyle='None', color='black', label='exp. [18]'),                  

                  ]

# Create the figure

ax1.legend(handles=legend_elements, loc=[1,0.65])





# ax1.legend(loc =[0.74,0.8])
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
# concatenated v. RMG-built 2,3,3,3-tetrafluoropropene_propane

tetra_mole_fractions = [0.5,
 0.5416666666666666,
 0.5833333333333333,
 0.625,
 0.6666666666666666,
 0.7083333333333333,
 0.75,
 0.7916666666666666,
 0.8333333333333333,
 0.875,
 0.9166666666666666,
 0.9583333333333333,
 1.0]

conc_blend = np.array([0.1900825 , 0.17705254, 0.16468832, 0.15362113, 0.14344375,
       0.13440333, 0.12457625, 0.11656158, 0.10861685, 0.1004934 ,
       0.0931222 , 0.08489082, 0.07680872])

RMG_built_259_species_in_core_= np.array([0.12851338, 0.11690963, 0.10562677, 0.09623334, 0.08819903,
       0.08112986, 0.07516694, 0.07014011, 0.06593628, 0.06227262,
       0.05959277, 0.05709261, 0.05473375])

#experimental
boxes_with_error_bars_x= [0.7199705458829688, 0.7769151721429506,0.8368641183400967, 0.9013470349522187]
boxes_with_error_bars_y= np.array([22.110780206833358,18.051348344024085,13.439815420866609,6.7140332504254445])                     

upper_error = np.array([25.785344940437234,21.818006283544968,15.736418379369027,7.72408037701269])-boxes_with_error_bars_y
lower_error = boxes_with_error_bars_y-np.array([18.436215473229485,14.285148579657019,11.419033904961381,5.427477418510271])




diamond_x = 1
diamond_y = 1.079853383950777


#plotting
fig = plt.figure()
ax1 = fig.add_subplot(111) 

ax1.plot(tetra_mole_fractions, conc_blend*100, '--', c='black', label='concatenated' )
ax1.plot(tetra_mole_fractions, RMG_built_259_species_in_core_*100, '-', c='black', label='RMG-built' )
ax1.plot(boxes_with_error_bars_x, boxes_with_error_bars_y, 's', c='black', markersize=12 )
ax1.plot(diamond_x, diamond_y, 'o', c='black', markersize=10 )
ax1.errorbar(boxes_with_error_bars_x, boxes_with_error_bars_y, yerr=[upper_error,lower_error],fmt='none',ecolor='black', capsize=5. )
# ax1.plot(1, 100*0.07680872, '*', markersize=12 )
# ax1.text(1,0.07680872 *100, "7.68 m/s", ha="left")



listOf_Yticks = np.arange(0, 45, 5)
plt.yticks(listOf_Yticks)

plt.xlabel(r'$CH_{2}=CFCF_{3}$ Mole Fraction', fontdict=fontdict)
plt.ylabel(r'$S_{L}$ (cm/s)',fontdict=fontdict)
#plt.title('Flame Speeds of 50/50  at Increasing Mole Fraction of ')
plt.title('2,3,3,3-tetrafluoropropene / propane', fontsize = 12, fontweight='bold')



legend_elements = [Line2D([0], [0],linestyle='-', color='black', lw=2, label='RMG-built'),
                   Line2D([0], [0], linestyle='--', color='black', label='concatenated'),
                   Line2D([0], [0], marker='s', markersize = 10, linestyle='None', color='black', label='exp. [9]'),                                

                  ]

# Create the figure

ax1.legend(handles=legend_elements, loc=[.65,0.75])





# ax1.legend(loc=(0.6, 0.75))

# %%
# pure propane, all good 

phis = [0.5486725663716815,
 0.5869359419375199,
 0.6250787649653435,
 0.6631016042780751,
 0.7010050251256282,
 0.7387895892129196,
 0.7764558547276145,
 0.814004376367615,
 0.8514357053682897,
 0.8887503895294486,
 0.9259489732420662,
 0.9630319975147564,
 1.0000000000000002,
 1.0368535150201303,
 1.0735930735930737,
 1.1102192034578575,
 1.1467324290998768,
 1.1831332717759313,
 1.2194222495390292,
 1.2555998772629644,
 1.2916666666666672,
 1.32762312633833,
 1.3634697617593161,
 1.3992070753278443,
 1.4348355663824608,
 1.4703557312252968,
 1.5057680631451125,
 1.5410730524401337,
 1.5762711864406782,
 1.6113629495315809,
 1.6463488231744117,
 1.6812292859294968,
 1.716004813477738,
 1.750675878642235,
 1.7852429514097181,
 1.8197064989517824,
 1.8540669856459335,
 1.8883248730964468,
 1.9224806201550388]


propane= np.array([0.06195943, 0.08925917, 0.12108564, 0.15518578, 0.19019072,
       0.22570115, 0.26182485, 0.29639055, 0.32894503, 0.35941137,
       0.38578687, 0.40935021, 0.42812927, 0.44230157, 0.4503138 ,
       0.45310761, 0.44843005, 0.43627199, 0.41690598, 0.38925824,
       0.3542967 , 0.31315461, 0.2693831 , 0.22686762, 0.19658242,
       0.17313805, 0.1530795 , 0.13498488, 0.12008105, 0.10692894,
       0.09490596, 0.08389711, 0.07460571, 0.0668977 , 0.06022409,
       0.05431326, 0.04920632, 0.04461791, 0.0404788 ])

#experimental 
# file:///Users/nora/Downloads/1-s2.0-S0010218005000428-main.pdf figure 5 

filled_diamond=[0.8, 27.33333333333333,
0.8993377483443709, 33.666666666666664,
1, 37.222222222222214,
1.099337748344371, 41.55555555555555,
1.2, 39.55555555555556,
1.2993377483443709, 30.888888888888886,
1.3986754966887418, 19.222222222222214]


dashed_line=[0.7486675087994702, 22.51413434062228,
0.809350126933124, 28.052833613362925,
0.8793289100921031, 33.03339506248544,
0.9387949324862948, 36.1279878340426,
1.0168336624192105, 38.55075485350568,
1.0989244410650119, 39.194618526104065,
1.1466365788150457, 38.514698487840164,
1.1996909454371527, 36.83329449711181,
1.3032389408749188, 31.471197831712423,
1.3630483572278296, 26.78791743828106,
1.3989526484259065, 23.555721801837148,
1.256763021376274, 34.1507744760176]

open_circles=[0.7353732569690578, 23.62893829946406,
0.860795447577233, 32.81632102429512,
0.9810912569445296, 38.116238855026424,
1.040660297526337, 38.877469677087035,
1.120141282085873, 38.633169403598274,
1.197051717582997, 36.61180539373795,
1.251543433203743, 32.37444658384331,
1.381758422350041, 23.004942420191554]

solid_line=[0.699728964054011, 20.972172825273795,
0.7986901973288856, 29.500239149364106,
0.8845583095205976, 34.58749800708863,
0.949346938274936, 37.12505672132353,
1.061867327291235, 38.538245502152336,
1.0989587804608838, 38.41683120960521,
1.148010154649922, 37.40320582788604,
1.205052796821153, 35.38736064950514,
1.258146408467114, 32.81705686849237,
1.3059615644047633, 29.803774880731915,
1.3498129729331976, 26.56937171169623,
1.3976771851506642, 22.444964986080272]



diamond_phis = []
diamond_speeds = []
for x in list(range(len(filled_diamond))):
    if x%2==0:
        diamond_phis.append(filled_diamond[x])
    else: 
        diamond_speeds.append(filled_diamond[x])
        
dashed_line_phis = []
dashed_line_speeds = []
for x in list(range(len(dashed_line))):
    if x%2==0:
        dashed_line_phis.append(dashed_line[x])
    else: 
        dashed_line_speeds.append(dashed_line[x])
        
open_circles_phis = []
open_circles_speeds = []
for x in list(range(len(open_circles))):
    if x%2==0:
        open_circles_phis.append(open_circles[x])
    else: 
        open_circles_speeds.append(open_circles[x])
         
solid_line_phis = []
solid_line_speeds = []
for x in list(range(len(solid_line))):
    if x%2==0:
        solid_line_phis.append(solid_line[x])
    else: 
        solid_line_speeds.append(solid_line[x])
         


#plotting
fig = plt.figure()
ax1 = fig.add_subplot(111) 

ax1.plot(phis, propane*100, '-', c='black', label='RMG model')
ax1.plot(diamond_phis, diamond_speeds, 'o', c='black')
ax1.plot(dashed_line_phis, dashed_line_speeds, '--', c='black' )
ax1.plot(open_circles_phis, open_circles_speeds,'x', c='black', markersize=10)
ax1.plot(solid_line_phis, solid_line_speeds,':', c='black' )

# ax1.plot(0.9630319975147564, 100*propane[11], '*', markersize=12 )
# ax1.text(0.9630319975147564,propane[11] *100, f"40.93 cm/s", ha="right")




plt.xlabel('Equivalence Ratio',fontweight='bold')
plt.ylabel(r'$S_{L}$ (cm/s)',fontdict=fontdict)
plt.title('propane', fontsize = 12, fontweight='bold')


legend_elements = [Line2D([0], [0],linestyle='-', color='black', lw=2, label='RMG model'),
#                    Line2D([0], [0], linestyle='--', color='black', label='concatenated'),
                   Line2D([0], [0], marker='x', markersize = 10, linestyle='None', color='black', label='exp. [21]'),                                
                   Line2D([0], [0],linestyle=':', markersize = 10, color='black', label='exp. [21]'),                                
                   Line2D([0], [0], marker='o', markersize = 10, linestyle='None', color='black', label='exp. [22]'),                                
                   Line2D([0], [0],linestyle='--', markersize = 10, color='black', label='exp. [22]'),                                

                  ]

# Create the figure

ax1.legend(handles=legend_elements, loc=[0.65, 0.5])





# ax1.legend(loc=[0.6, 0.8])

#for concatenated model, the 0.0 volume fraction (pure propane) is 0.41746168425980656 m/s. Lines up with this

# %%
# pure difluoromethane

difluoromethane_phis = [0.4, 0.4827586206896552, 0.5241379310344828, 0.5655172413793104, 0.6482758620689656, 0.7310344827586208, 0.7724137931034484, 0.8137931034482759, 0.8551724137931036, 0.8965517241379312, 0.9379310344827587, 0.9793103448275863, 1.020689655172414, 1.0620689655172415, 1.103448275862069, 1.1448275862068966, 1.1862068965517243, 1.227586206896552, 1.2689655172413796, 1.310344827586207, 1.3517241379310345, 1.3931034482758622, 1.4344827586206899, 1.4758620689655175, 1.5172413793103452, 1.5586206896551724, 1.6]
difluoromethane_speeds =np.array([0.0037681699622848534, 0.008872611358313194, 0.012712865073363258, 0.017794067448184712, 0.030515062264068946, 0.04592604264559624, 0.05401815132920128, 0.06029617526279927, 0.06620414710133933, 0.07063572222005558, 0.07363101983742808, 0.07513871506630403, 0.07534829972784167, 0.0741287823718414, 0.072025667194897, 0.06882644624821621, 0.06495046515913869, 0.06064601057863507, 0.056049202268005735, 0.0514352563188021, 0.046898553015092735, 0.04265850525833517, 0.03871475785743218, 0.035143972532464145, 0.03207615830695433, 0.02944831842679974, 0.027209857566558925])*100



#experimental
# Method of test for burning velocity measurementof flammable gases and results by Denis Clodic and Tony Jabbour
# Source 6 in Papas: D. Clodic, T. Jabbour, HVAC&R Res. 17(1) (2011) 51–75.
# did equivalence ratios correct as this source says! equivalence ratio of 1 = volume fraction of 17.4
boxes_equiv_ratios = [0.89, 0.94, 1, 1, 1.12, 1.12, 1.19, 1.27,1.50]
boxes_speeds = np.array([0.046,0.055,0.060,0.065,0.067,0.066,0.064,0.057,0.037])*100 #m/s


open_circles = [0.9086725663716814, 5.823233326138572,
0.9439948197712066, 6.224286639326571,
0.9738812864234837, 6.330144614720484,
1.0109026548672566, 6.6366846535722,
1.0846000431685732, 6.659218648823657,
1.1827688322900927, 6.52784804662206,
1.270121303690913, 5.900574142024607,
1.3451517375350743, 5.202616015540688]
      
open_circles_phis = []
open_circles_speeds = []
for x in list(range(len(open_circles))):
    if x%2==0:
        open_circles_phis.append(open_circles[x])
    else: 
        open_circles_speeds.append(open_circles[x])
      
    
    

#plotting
fig = plt.figure()
ax1 = fig.add_subplot(111) 

ax1.plot(difluoromethane_phis, difluoromethane_speeds, '-', c='black', label='RMG model')
ax1.plot(boxes_equiv_ratios, boxes_speeds, 'o', c='black')
ax1.plot(open_circles_phis, open_circles_speeds, 'x', c='black')# label='RMG model')

# ax1.plot(0.9793103448275863, difluoromethane_speeds[11], '*', markersize=12 )
# ax1.text(0.9793103448275863,difluoromethane_speeds[11], f"7.51 cm/s", ha="right")






plt.xlabel('Equivalence Ratio',fontweight='bold')
plt.ylabel(r'$S_{L}$ (cm/s)',fontdict=fontdict)
plt.title('difluoromethane', fontsize = 12, fontweight='bold')
# ax1.legend(bbox_to_anchor=(0.95, 0.3))


legend_elements = [Line2D([0], [0],linestyle='-', color='black', lw=2, label='RMG model'),
#                    Line2D([0], [0], linestyle='--', color='black', label='concatenated'),
                   Line2D([0], [0], marker='o', markersize = 10, linestyle='None', color='black', label='exp. [19]'),                                
                   Line2D([0], [0], marker='x', markersize = 10, linestyle='None', color='black', label='exp. [20]'),                                

                  ]

# Create the figure

ax1.legend(handles=legend_elements, loc=[.55,0.07])

# %%
 difluoromethane_speeds[11]
# Out:
# 7.5138715066304025

# %%
# Out:
# 7.5138715066304025

# %%
# pure 2,3,3,3-tetrafluoropropane


tetra_phis_184=[0.5201,
          .6343,
          .7463,
          .8563,
          .9644,
          1.070,
          1.17479,
          1.2772, 
          1.3779,
          1.4768,
          1.5740,
          1.6699
         ]
tetra_speeds_184 = np.array([0.01865402867844926,
                       0.03658286109584259,
                       0.05762400275805327,
                       0.07480424580535054,
                       0.08440790680554607,
                       0.08590363931595058,
                       0.0805087560741039, 
                       0.06927376074429673,
                       0.05387019219217971,
                       0.040073882305163074,
                       0.03022327777144476,
                       0.0238850810820577
                       
                      ])


_168_retrieved = [0.5201612903225807,
 0.6342962507682852,
 0.7463459196102316,
 0.8563669281834642,
 0.9644138755980862,
 1.0705394190871371,
 1.1747943595769683,
 1.2772277227722773,
 1.3778868360277137,
 1.476817401259302,
 1.5740635641316687,
 1.6696679797411367,
 1.763671875,
 1.8561151079136693,
 1.9470362239297476,
]

_168_speeds_retrieved=np.array([0.01535207, 0.03191965, 0.05006807, 0.06511845, 0.07349454,
       0.07663185, 0.07497845, 0.06931936, 0.06022201,
       0.04989278, 0.04025256, 0.03187205, 0.02536772, 0.02024686, 0.01663119])





#experimental
open_squares=[0.9634877695960248, 1.1766155329808186,
0.9661308117915315, 1.3265840681927772,
0.9975727163510653, 1.5262097598051638,
1.0004266134898128, 1.369032927696369,
1.0018535620591864, 1.290444511641972,
1.0019173089024918, 1.197586609893837,
1.0361199421374807, 1.3757508642600873,
1.0388120203662992, 1.454290244281173,
1.1060943616734364, 1.4463464068846594,
1.107575249879453, 1.2891859201203022,
1.1075115030361478, 1.3820438218684368,
1.1747300974999795, 1.4669578862200576,
1.1746663506566741, 1.5598157879681922,
1.176014841572749, 1.5955140202191915,
1.2530112210789563, 1.437454539510784,
1.2529670886489757, 1.5017407791825699,
1.3203131767994183, 1.4009390400379216,
1.3230248694415612, 1.450906757982658,
1.3943722979102477, 1.5214859552627928,
1.3957943428762902, 1.4500404547274828,
1.4671074461216584, 1.5706200606412284,
1.46852458748437, 1.5063174756250053,
1.542652359041836, 1.5268635735826546,
1.5455013525772523, 1.3768296569929475]

open_squares_phis = []
open_squares_speeds = []
for x in list(range(len(open_squares))):
    if x%2==0:
        open_squares_phis.append(open_squares[x])
    else: 
        open_squares_speeds.append(open_squares[x])
        
        
        
filled_diamonds=[1.037512565483536, 1.3471628568393008,
1.178888353124821, 1.4097655260340474,
1.3201562614928202, 1.6295123366487143,
1.4711725332832075, 1.6491430953178765]
#1.6236942112962676, 1.4758987896272446]        
        
filled_diamonds_phis = []
filled_diamonds_speeds = []
for x in list(range(len(filled_diamonds))):
    if x%2==0:
        filled_diamonds_phis.append(filled_diamonds[x])
    else: 
        filled_diamonds_speeds.append(filled_diamonds[x])
         
        
        
        

#plotting
fig = plt.figure()
ax1 = fig.add_subplot(111) 

# ax1.plot(difluoromethane_phis, difluoromethane_speeds, '-', c='black', label='RMG model')
# ax1.plot(boxes_equiv_ratios, boxes_speeds, 'o', c='black')
ax1.plot(open_squares_phis, open_squares_speeds, 'x', c='black', markersize=12)
# ax1.plot(tetra_phis_184[4:], tetra_speeds_184[4:]*100, '-', c='black', label='RMG model')
ax1.plot(filled_diamonds_phis, filled_diamonds_speeds, 's', c='black', markersize=10)
ax1.plot(_168_retrieved[4:-4], _168_speeds_retrieved[4:-4]*100, '-', c='black', label='RMG model')

# ax1.plot(0.9644138755980862, (_168_speeds_retrieved[4]*100), '*', markersize=12 )
# ax1.text(0.9644138755980862,(_168_speeds_retrieved[4]*100)-.5, f"7.35 cm/s", ha="left")
# ax1.plot(1.5740635641316687, (_168_speeds_retrieved[-5]*100), '*', markersize=12 )
# ax1.text(1.5740635641316687,(_168_speeds_retrieved[-5]*100)-.5, f"4.02 cm/s", ha="left")





listOf_Yticks = np.arange(0, 9, 1)
plt.yticks(listOf_Yticks)


plt.xlabel('Equivalence Ratio',fontweight='bold')
plt.ylabel(r'$S_{L}$ (cm/s)',fontdict=fontdict)
plt.title('2,3,3,3-tetrafluoropropane', fontsize = 12, fontweight='bold')
# ax1.legend(bbox_to_anchor=(0.75, 0.95))


legend_elements = [Line2D([0], [0],linestyle='-', color='black', lw=2, label='RMG model'),
#                    Line2D([0], [0], linestyle='--', color='black', label='concatenated'),
                   Line2D([0], [0], marker='x', markersize = 10, linestyle='None', color='black', label='exp. [18]'),                                
                   Line2D([0], [0], marker='s', markersize = 10, linestyle='None', color='black', label='exp. [18]'),                                
                  ]

# Create the figure

ax1.legend(handles=legend_elements, loc=[.8,0.75])








# ax1.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))


#used 168 for concatenated blend! at 1.0 mole fraction {pure tetra}, concatenated flamespeed is 0.07361851. For a 0.9644138755980862 phi in 168 pure propane model, speed is 0.0734945407570938:
#this is now plotting 168

# %%
_168_speeds_retrieved[4]
# Out:
# 0.07349454
