# %%
# %matplotlib notebook
import matplotlib.pylab as plt
from labellines import labelLine, labelLines

# %%
#1 day 1 hour 

vf_CH2F2_C2H5F_CH2FCHF2 = [0.11, 0.1125, 0.115, 0.11750000000000001, 0.12000000000000001, 0.12250000000000001, 0.125, 0.1275, 0.13, 0.1325, 0.135, 0.1375, 0.14, 0.14250000000000002, 0.14500000000000002, 0.14750000000000002]
fs_CH2F2_C2H5F_CH2FCHF2 = [0.0038621407994663447, 0.003615970412508458, 0.0033923849085611994, 0.003190762947441273, 0.002998536788935894, 0.0028255765580354124, 0.002668893529999747, 0.00252667074294026, 0.002394494279955528, 0.0022746267158410367, 0.002161641153593256, 0.0020558327145740996, 0.0019584253682472163, 0.0018693416197547654, 0.0017852018142583185, 0.0017066639935261673]
speeds_CH2F2_C2H5F_CH2FCHF2 = [x*100 for x in fs_CH2F2_C2H5F_CH2FCHF2]

# %%
#3 days 21 hours 

vf_CH2F2_C2H5F_CH2FCHF2_3d = [0.11, 0.1125, 0.115, 0.11750000000000001, 0.12000000000000001, 0.12250000000000001, 0.125, 0.1275, 0.13, 0.1325, 0.135, 0.1375, 0.14, 0.14250000000000002, 0.14500000000000002, 0.14750000000000002]
fs_CH2F2_C2H5F_CH2FCHF2_3d = [0.004065352313995489, 0.003826531230357129, 0.0036065824266204504, 0.0034096230787413664, 0.0032344690101590487, 0.0030655879153561947, 0.002907247933113594, 0.0027644364839190107, 0.0026289360035591717, 0.0025137058299689327, 0.0024044732679606947, 0.0022948440705637656, 0.002194273137032473, 0.002097680061396072, 0.0020072669997522946, 0.0019269801790301395]
speeds_CH2F2_C2H5F_CH2FCHF2_3d = [x*100 for x in fs_CH2F2_C2H5F_CH2FCHF2_3d]

# %%
#4 days 1 hour 

vf_CH2F2_C2H5F_CH2FCHF2_4d = [0.11, 0.1125, 0.115, 0.11750000000000001, 0.12000000000000001, 0.12250000000000001, 0.125, 0.1275, 0.13, 0.1325, 0.135, 0.1375, 0.14, 0.14250000000000002, 0.14500000000000002, 0.14750000000000002]
fs_CH2F2_C2H5F_CH2FCHF2_4d = [0.004065304132338803, 0.0038263855152577586, 0.0036064122073040483, 0.0034095688524075985, 0.003235668620705832, 0.003065817686370287, 0.002907187746430691, 0.0027643892965501164, 0.0026289002946400407, 0.0025136781202214934, 0.0024044454132888683, 0.002294660504881128, 0.0021941090043290667, 0.0020976638587430598, 0.0020072739385077003, 0.001926643765564944]
speeds_CH2F2_C2H5F_CH2FCHF2_4d = [x*100 for x in fs_CH2F2_C2H5F_CH2FCHF2_4d]

# %%
#plotting
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(vf_CH2F2_C2H5F_CH2FCHF2, speeds_CH2F2_C2H5F_CH2FCHF2, '-', c='b', label='1 day 1 hour' )
ax1.plot(vf_CH2F2_C2H5F_CH2FCHF2_3d, speeds_CH2F2_C2H5F_CH2FCHF2_3d, '-', c='r', label='3 days 21 hours' )
ax1.plot(vf_CH2F2_C2H5F_CH2FCHF2_4d, speeds_CH2F2_C2H5F_CH2FCHF2_4d, '-', c='g', label='4 days 1 hour' )


xvals = [0,0, 0.12]#,0.150,0.050]
labelLines(ax1.get_lines(), fontsize=8, xvals=xvals)


plt.xlabel('refrigerant volume fraction')
plt.ylabel('Su (cm/s)')
# Out:
# <img src="data:image/png;base64,..." width="1151.1111416051426">
# Text(0, 0.5, 'Su (cm/s)')
