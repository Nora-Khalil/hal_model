# %%
import pandas as pd 


csvData = pd.read_csv("final_calcs_alternative.csv")

csvData.sort_values(["species"], axis=0, ascending=[True], inplace=True)


pd.options.display.max_rows = 4000
print(csvData)
# Out:
#      species  [0.125] ['speed_for_volfrac0.1852880613198675']
# 95        39       []                                      []
# 34        40  [0.125]                    [0.2286514013995879]
# 42        41  [0.125]                    [0.2009589267155669]
# 75        42  [0.125]                   [0.20095895251788098]
# 131       43  [0.125]                   [0.20098945281514285]
# 101       44  [0.125]                   [0.26730880688881326]
# 114       45  [0.125]                     [0.150798288501649]
# 82        46  [0.125]                   [0.14894235904527017]
# 78        47  [0.125]                   [0.13529898692709103]
# 19        48  [0.125]                   [0.09158775245458096]
# 87        49  [0.125]                   [0.09132058563425681]
# 109       50  [0.125]                    [0.0920667311600813]
# 61        51  [0.125]                   [0.15033798858055275]
# 50        52  [0.125]                    [0.1317357062481404]
# ...
