fs_CH3CF3 = [0.04052308086473601, 0.04665393853063239, 0.05271219344009699, 0.058171094096665495, 0.06414853782125196, 0.07000530107572102, 0.07435250165716567, 0.07864776182716632, 0.08185689365755584, 0.08403099798894387, 0.08486272229565936, 0.08461834259939639, 0.08332224229841236, 0.08055823129532712, 0.07673196026609741, 0.07184187396474088, 0.06591333687212016, 0.05928467114796014, 0.05212203023355726, 0.04484875449336338, 0.038385979155229094, 0.032466355247033285, 0.02544576410191881, 0.021292048120250973, 0.018547293366225168, 0.016572515083045716, 0.014707835098455451, 0.013089239660783927, 0.011707686569874294, 0.010458256646147504, 0.009443320593326584, 0.00849030827664599]
speeds_CH3CF3 = [x*100 for x in fs_CH3CF3]

# %%
#CH3CF3_CH2FCHF2 data (did not complete on short, will have to rerun on west)

list_of_files = os.listdir('/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/blends_of_two_equal_parts_species_in_core/flamespeeds/CH3CF3_CH2FCHF2/data/')

#get volume fraction list from data folder
CH3CF3_CH2FCHF2_vol_fracs = []
for file in list_of_files:
    match = re.search('(0\.[0-9]+)\.csv',file)
    if match:
        CH3CF3_CH2FCHF2_vol_fracs.append(float(match.group(1)))

#get speed
CH3CF3_CH2FCHF2_speeds = []
for file in list_of_files:
    match = re.search('(0\.[0-9]+)\.csv',file)
    if match:
        df = pd.read_csv(f'/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/blends_of_two_equal_parts_species_in_core/flamespeeds/CH3CF3_CH2FCHF2/data/{file}')
        CH3CF3_CH2FCHF2_speeds.append(df['velocity'][0])

# %%
import os
import re
import numpy as np
import matplotlib.pylab as plt
from labellines import labelLine, labelLines
import pandas as pd


'''want to make a silly little block that plots all of these things for me'''

directory = '/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/blends_of_two_equal_parts'

list_of_blends = [file for file in os.listdir(directory) if re.match('[A-Z0-9]+_[A-Z0-9]+', file)]

flame_spd_dir = '/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/concatenate_equal_parts/flamespeeds'

max_speeds_for_blends = {}

for folder in list_of_blends: 
   
    try: 
        df = pd.read_csv(f'{directory}/{folder}/blend_flamespeeds.csv')
        volume_fractions = [float(i) for i in df.columns]
        speeds = df.values[0,:] * 100

    except:
        print(folder)
        # get flamespeed of RMG generated blend 
        with open(f'{directory}/{folder}/final_calcs.csv','r') as f: 
            values = f.readlines()
        volume_fractions = [float(x) for x in values[0].split(',')]
        speed = [float(x) for x in values[1].split(',')]
        speeds = [x*100 for x in speed]

    
     # get flamespeed of concatenated blend
 
    df = pd.read_csv(f'{flame_spd_dir}/{folder}/concatenated_blend.csv')
    conc_volume_fractions = [float(i) for i in df.columns]
    conc_speeds = df.values[0,:] * 100 
    
    
    #plotting 

    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    ax1.plot(volume_fractions, speeds, '.-', c='green', label='previous RMG blend' )


    ax1.plot(conc_volume_fractions,conc_speeds, '.-', c='m', label = 'concatenated')


    #plot individual species too 
    match = re.match('([A-Z0-9]+)_([A-Z0-9]+)', folder)
    species = [match.group(1),match.group(2)]
    colors = ['blue','red']
    for group,color in zip(species,colors): 
        vol_f = f'volfrac_{group}'
        speeds_ = f'speeds_{group}'
        ax1.plot(globals()[vol_f], globals()[speeds_] ,'.-', c=color,label=str(group))
        
    #get flamespeeds of blends with core 
    core_direc = '/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/blends_of_two_equal_parts_species_in_core/flamespeeds'

    try:
        
        df = pd.read_csv(f'{core_direc}/{folder}/blend_flamespeeds.csv')
        volume_fractions = [float(i) for i in df.columns]
        speeds = df.values[0,:] * 100

        #find the index of the max, and the corresponding volume fraction. Save this to dictionary
        max_speed = max(speeds)
        max_speeds_for_blends[folder] = volume_fractions[speeds.argmax()]
        
        
        ax1.plot(volume_fractions, speeds, '.-', c='orange', label='new RMG blend' )
        
        ax1.plot(volume_fractions[speeds.argmax()],max_speed,"*", c='black')

    except:
        pass
        
    if folder == 'CH3CF3_CH2FCHF2':
        ax1.plot(CH3CF3_CH2FCHF2_vol_fracs, np.array(CH3CF3_CH2FCHF2_speeds)*100, '.-', c='orange', label='new RMG blend' )
        
        #find the index of the max, and the corresponding volume fraction. Save this to dictionary
        speeds = np.array(CH3CF3_CH2FCHF2_speeds)*100
        max_speed = max(speeds)
        max_speeds_for_blends[folder] = CH3CF3_CH2FCHF2_vol_fracs[speeds.argmax()]
        
        
        ax1.plot(CH3CF3_CH2FCHF2_vol_fracs[speeds.argmax()],max_speed,"*", c='black')
    plt.xlabel('refrigerant volume fraction')
    plt.ylabel('Su (cm/s)')
    plt.title(f'Blend of {species[0]}:{species[1]}')
    plt.legend()

    

        

print(max_speeds_for_blends)
# Out:
# {'C2H5F_CH2F2': 0.10258620689655173, 'C2H5F_CH2FCH2F': 0.0793103448275862, 'C2H5F_CH2FCHF2': 0.08706896551724139, 'C2H5F_CH3CHF2': 0.0793103448275862, 'C2H5F_CH3F': 0.09482758620689655, 'CH2F2_CH3CF3': 0.12586206896551724, 'CH2F2_CH3F': 0.14913793103448275, 'CH2FCH2F_CH2F2': 0.1103448275862069, 'CH2FCH2F_CH2FCHF2': 0.08706896551724139, 'CH2FCH2F_CH3CHF2': 0.0793103448275862, 'CH2FCH2F_CH3F': 0.10258620689655173, 'CH2FCHF2_CH2F2': 0.12586206896551724, 'CH2FCHF2_CH3F': 0.1103448275862069, 'CH3CF3_C2H5F': 0.09482758620689655, 'CH3CF3_CH2FCH2F': 0.08706896551724139, 'CH3CF3_CH2FCHF2': 0.09482758620689655, 'CH3CF3_CH3CHF2': 0.08706896551724139, 'CH3CHF2_CH2F2': 0.1103448275862069, 'CH3CHF2_CH2FCHF2': 0.08706896551724139, 'CH3F_CH3CF3': 0.1103448275862069, 'CH3F_CH3CHF2': 0.10258620689655173}
# ...

# %%
import os
import re
path_ = '/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/blends_of_two_equal_parts_species_in_core/'



list_of_blend_files = [file for file in os.listdir(path_) if re.match('[A-Z0-9]+_[A-Z0-9]+',file)]


list_of_blend_files
# Out:
# ['C2H5F_CH2F2',
#  'C2H5F_CH2FCH2F',
#  'C2H5F_CH2FCHF2',
#  'C2H5F_CH3CHF2',
#  'C2H5F_CH3F',
#  'CH2F2_CH3CF3',
#  'CH2F2_CH3F',
#  'CH2FCH2F_CH2F2',
#  'CH2FCH2F_CH2FCHF2',
#  'CH2FCH2F_CH3CHF2',
#  'CH2FCH2F_CH3F',
#  'CH2FCHF2_CH2F2',
#  'CH2FCHF2_CH3F',
#  'CH3CF3_C2H5F',
#  'CH3CF3_CH2FCH2F',
#  'CH3CF3_CH2FCHF2',
#  'CH3CF3_CH3CHF2',
#  'CH3CHF2_CH2F2',
#  'CH3CHF2_CH2FCHF2',
#  'CH3F_CH3CF3',
#  'CH3F_CH3CHF2']

# %%
len(list_of_blend_files)
# Out:
# 21
