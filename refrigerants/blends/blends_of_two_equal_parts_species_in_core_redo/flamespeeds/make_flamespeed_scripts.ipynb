# %%
import os 
import re
import cantera as ct
import rmgpy.chemkin

# %% [markdown]
# We need a list so we can identify the species in each merged model, as they change for each model and are even sometimes called S(bleh bleh)

# %%
# list_of_blends = [file for file in os.listdir('/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/concatenate_equal_parts') if re.match('[A-Z0-9]+_[A-Z0-9]+', file)]
# list_of_blends            
list_of_blends = ['C2H5F_CH2F2',
 'C2H5F_CH2FCH2F',
 'C2H5F_CH2FCHF2',
 'C2H5F_CH3CHF2',
 'C2H5F_CH3F',
 'CH2F2_CH3CF3',
 'CH2FCH2F_CH2F2',
 'CH2FCH2F_CH2FCHF2',
 'CH2FCH2F_CH3CHF2',
 'CH3CF3_C2H5F',
 'CH3CF3_CH2FCH2F',
 'CH3CF3_CH2FCHF2',
 'CH3CF3_CH3CHF2',
 'CH3CHF2_CH2F2',
 'CH3CHF2_CH2FCHF2',
 'CH3F_CH3CF3',
 'CH3F_CH3CHF2']

# %%
# os.mkdir('/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/blends_of_two_equal_parts_species_in_core_redo/flamespeeds')
for file in blends_: 
    
    os.makedirs(f'/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/blends_of_two_equal_parts_species_in_core_redo/flamespeeds/{file}', exist_ok=True)

# %%
blends_= ['C2H5F_CH2F2',
 'C2H5F_CH2FCH2F',
 'C2H5F_CH2FCHF2',
 'C2H5F_CH3CHF2',
 'C2H5F_CH3F',
 'CH2F2_CH3CF3',
 'CH2F2_CH3F',
 'CH2FCH2F_CH2F2',
 'CH3CF3_C2H5F',
 'CH3CF3_CH2FCH2F',
 'CH3CF3_CH2FCHF2',
 'CH3CF3_CH3CHF2',
 'CH3CHF2_CH2F2',
 'CH3CHF2_CH2FCHF2',
 'CH3F_CH3CF3']

# %%
#dictionary with composition of each species 

compositions = {'C2H5F':{'C': 2,'H': 5,'F': 1},
                 'C2H6':{'C': 2,'H': 6},
                 'CH2F2': {'C':1,'H':2,'F':2},
                 'CH2FCH2F':{'C':2,'H':4,'F':2},
                 'CH2FCHF2': {'C':2,'H':3,'F':3},
                 'CH3CF3': {'C':2,'H':3,'F':3},
                 'CH3CHF2': {'C':2,'H':4,'F':2},
                 'CH3F':{'C':1,'H':3,'F':1},
                 'CH4': {'C':1,'H':4},
}

smiles = {'C2H5F':'CCF',
         'C2H6':'CC',
         'CH2F2': 'FCF',
         'CH2FCH2F':'FCCF',
         'CH2FCHF2': 'FCC(F)F',
         'CH3CF3': 'CC(F)(F)F',
         'CH3CHF2': 'CC(F)F',
         'CH3F': 'CF',
         'CH4': 'C',
          'O2': '[O][O]',
}

# %%
#get the species ID's of each of the species in the blends

for blend in blends_: 
    
    match = re.findall('([A-Z0-9]+)_([A-Z0-9]+)',blend)
    spec1 = match[0][0]
    spec2 = match[0][1]
    

    direc = f'/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/blends_of_two_equal_parts_species_in_core_redo/{blend}/chemkin'
    spcs, rxns = rmgpy.chemkin.load_chemkin_file(f'{direc}/copies/copy_chem.inp',f'{direc}/species_dictionary.txt', f'{direc}/tran.dat' )

    for species in spcs: 
        if species.smiles == smiles[spec1]: 
            print(f'{spec1} is: {species}')
        if species.smiles == smiles[spec2]: 
            print(f'{spec2} is: {species}')
    print('******************************************')

#i know some of the species in the dictionary have the same label (ex S(179)) but 
# but i've confirmed that it is still correct and that the adjacency list of the species for each model 
# is what it should be
# Out:
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.falloff.Troe'> for duplicate reaction C2H3O(224) <=> CO(11) + CH3(16). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HO2(9) + CH2CHF(39) <=> CHF-2(226) + CH3O2(57). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H4(25) <=> CO2(97) + C2H4(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CHF(39) <=> CO2(97) + CH2CHF(39). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CHF(39) <=> CO2(97) + CH2CHF(39). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CHF(39) <=> CO2(97) + CH2CHF(39). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CHF(39) <=> CO2(97) + CH2CHF(39). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CHF(39) <=> CO2(97) + CH2CHF(39). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CHF(39) <=> CO2(97) + CH2CHF(39). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CO2(12) <=> CO2(12) + CO2(97). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CO2(12) <=> CO2(12) + CO2(97). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CO2(12) <=> CO2(12) + CO2(97). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CHFO(36) <=> CO2(97) + CHFO(36). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CHFO(36) <=> CO2(97) + CHFO(36). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CHFO(36) <=> CO2(97) + CHFO(36). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CHFO(36) <=> CO2(97) + CHFO(36). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CHFO(36) <=> CO2(97) + CHFO(36). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CHFO(36) <=> CO2(97) + CHFO(36). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H2(20) <=> CO2(97) + C2H2(20). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2O(17) <=> CO2(97) + CH2O(17). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2O(17) <=> CO2(97) + CH2O(17). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2O(17) <=> CO2(97) + CH2O(17). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CH2CHF(39) <=> O(7) + FC1CO1(76). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CH2CHF(39) <=> O2(2) + CH2CHF(39). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CF2O(181) <=> O(7) + CF2O2(195). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CF2O(181) <=> O(7) + CF2O2(209). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CF2O(181) <=> O2(2) + CF2O(181). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2O(17) <=> CO2(97) + CH2O(17). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2O(17) <=> CO2(97) + CH2O(17). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2O(17) <=> CO2(97) + CH2O(17). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CO2(12) <=> O2(2) + CO2(12). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CO2(12) <=> O2(2) + CO2(97). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H4O(225) <=> CO2(97) + C2H4O(225). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H4O(225) <=> CO2(97) + C2H4O(225). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H4O(225) <=> CO2(97) + C2H4O(225). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H4O(225) <=> CO2(97) + C2H4O(225). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H4O(225) <=> CO2(97) + C2H4O(225). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H4O(225) <=> CO2(97) + C2H4O(225). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CF2O(181) + CO2(12) <=> CF2O(181) + CO2(97). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CF2O(181) + CO2(12) <=> CF2O(181) + CO2(97). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CF2O(181) + CO2(12) <=> CF2O(181) + CO2(97). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CF2O(181) + CO2(12) <=> CF2O(181) + CO2(97). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CF2O(181) + CO2(12) <=> CF2O(181) + CO2(97). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CF2O(181) + CO2(12) <=> CF2O(181) + CO2(97). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CHF2(53) + CH2CHF(39) <=> CHF-2(226) + C2H3F2(45). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CH2O(17) <=> O(7) + C1OO1(113). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CH2O(17) <=> O2(2) + CH2O(17). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CH2CO(23) + CH2CO(23) <=> HCCO(18) + C2H3O(224). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CHFO(36) + CH2CHF(39) <=> CHF(33) + C2H3FO(66). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CHFO(36) + CH2CHF(39) <=> CHF-2(226) + C2H3FO(66). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HF(31) + CO2(12) + CH2CO(23) <=> CHO2(60) + CH2CFO(52). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HF(31) + CO2(12) + CH2CO(23) <=> CO2(12) + C2H3FO(63). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF3(182) <=> CO2(97) + C2HF3(182). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF3(182) <=> CO2(97) + C2HF3(182). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF3(182) <=> CO2(97) + C2HF3(182). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF3(182) <=> CO2(97) + C2HF3(182). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF3(182) <=> CO2(97) + C2HF3(182). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF3(182) <=> CO2(97) + C2HF3(182). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CH2CO(23) <=> O2(2) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CH2CO(23) <=> O2(2) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CH2CO(23) <=> O2(2) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H3FO(63) <=> CO2(97) + C2H3FO(63). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H3FO(63) <=> CO2(97) + C2H3FO(63). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H3FO(63) <=> CO2(97) + C2H3FO(63). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H3FO(63) <=> CO2(97) + C2H3FO(63). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H3FO(63) <=> CO2(97) + C2H3FO(63). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H3FO(63) <=> CO2(97) + C2H3FO(63). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF(41) <=> CO2(97) + C2HF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF(41) <=> CO2(97) + C2HF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF(41) <=> CO2(97) + C2HF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF(41) <=> CO2(97) + C2HF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF(41) <=> CO2(97) + C2HF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF(41) <=> CO2(97) + C2HF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CF2O(181) + CH2CF2(40) <=> CF2(178) + S(214). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HO2(9) + CH2CO(23) <=> CO(11) + CH3O2(57). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CHF-2(226) + C2H2(20) <=> CH2(222) + C2HF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CHF-2(226) + C2H2(20) <=> F(30) + C3H3(102). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CHF-2(226) + C2H2(20) <=> H(6) + C3H2F(91). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + C2H3FO(63) <=> O2(2) + C2H3FO(63). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + C2H4O(225) <=> O2(2) + C2H4O(225). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + C2HF3(182) <=> O(7) + S(201). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + C2HF3(182) <=> O2(2) + C2HF3(182). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HO2(9) + C2HF3(182) <=> CHF-2(226) + CHF2O2(90). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CF2(40) <=> CO2(97) + CH2CF2(40). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CF2(40) <=> CO2(97) + CH2CF2(40). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CF2(40) <=> CO2(97) + CH2CF2(40). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CF2(40) <=> CO2(97) + CH2CF2(40). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CF2(40) <=> CO2(97) + CH2CF2(40). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CF2(40) <=> CO2(97) + CH2CF2(40). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HO2(9) + CH2CF2(40) <=> CHF2O2(90) + CH2(222). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2F4(183) <=> CO2(97) + C2F4(183). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CF2O(181) + CH2CF2(40) <=> CF2-2(227) + S(214). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HO2(9) + CH2CF2(40) <=> CF2-2(227) + CH3O2(57). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CHFO(36) <=> O(7) + CHFO2(189). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CHFO(36) <=> O2(2) + CHFO(36). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CH2CO(23) + CH2CFO(52) <=> HCCO(18) + C2H3FO(66). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HF(31) + HCCO(18) <=> S(300). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H2F2(42) <=> CO2(97) + C2H2F2(42). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CH2CF2(40) <=> O(7) + S(215). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CH2CF2(40) <=> O2(2) + CH2CF2(40). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + C2HF(41) <=> O(7) + C2HFO(211). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + C2HF(41) <=> O2(2) + C2HF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# C2H5F is: C2H5F(1)
# CH2F2 is: CH2F2(34)
# ******************************************
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.falloff.Troe'> for duplicate reaction C2H3O(182) <=> CO(13) + CH3(18). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HF(33) + C2HFO(79) <=> CO(13) + CH2F2(36). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO(13) + CH2F2(36) <=> F(32) + C2H2FO(80). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CHFO(38) + CH2CHF(41) <=> CHF(35) + C2H3FO(68). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CH2CHF(41) <=> O(7) + FC1CO1(78). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CH2CHF(41) <=> O2(2) + CH2CHF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CHF(41) <=> CO2(99) + CH2CHF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CHF(41) <=> CO2(99) + CH2CHF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CHF(41) <=> CO2(99) + CH2CHF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CHF(41) <=> CO2(99) + CH2CHF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CHF(41) <=> CO2(99) + CH2CHF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CHF(41) <=> CO2(99) + CH2CHF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H4(27) <=> CO2(99) + C2H4(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H2F2(44) <=> CO2(99) + C2H2F2(44). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CF2(42) <=> CO2(99) + CH2CF2(42). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CF2(42) <=> CO2(99) + CH2CF2(42). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CF2(42) <=> CO2(99) + CH2CF2(42). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CF2(42) <=> CO2(99) + CH2CF2(42). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CF2(42) <=> CO2(99) + CH2CF2(42). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CF2(42) <=> CO2(99) + CH2CF2(42). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HO2(9) + CH2CF2(42) <=> CHF2O2(92) + CH2(244). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CH2CF2(42) <=> O(7) + S(203). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CH2CF2(42) <=> O2(2) + CH2CF2(42). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CHFO(38) <=> O(7) + CHFO2(210). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CHFO(38) <=> O2(2) + CHFO(38). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CHFO(38) <=> CO2(99) + CHFO(38). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CHFO(38) <=> CO2(99) + CHFO(38). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CHFO(38) <=> CO2(99) + CHFO(38). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CHFO(38) <=> CO2(99) + CHFO(38). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CHFO(38) <=> CO2(99) + CHFO(38). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CHFO(38) <=> CO2(99) + CHFO(38). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H2(22) <=> CO2(99) + C2H2(22). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CHFO(38) + C2H2F2(44) <=> CHF(35) + S(205). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HF(43) <=> CO2(99) + C2HF(43). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HF(43) <=> CO2(99) + C2HF(43). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HF(43) <=> CO2(99) + C2HF(43). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O(19) <=> CO2(99) + CH2O(19). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O(19) <=> CO2(99) + CH2O(19). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O(19) <=> CO2(99) + CH2O(19). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CH2O(19) <=> O(7) + C1OO1(115). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CH2O(19) <=> O2(2) + CH2O(19). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O(19) <=> CO2(99) + CH2O(19). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O(19) <=> CO2(99) + CH2O(19). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O(19) <=> CO2(99) + CH2O(19). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HF(43) <=> CO2(99) + C2HF(43). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HF(43) <=> CO2(99) + C2HF(43). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HF(43) <=> CO2(99) + C2HF(43). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CH2CO(25) + CH2CO(25) <=> HCCO(20) + C2H3O(182). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H4O(183) <=> CO2(99) + C2H4O(183). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H4O(183) <=> CO2(99) + C2H4O(183). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H4O(183) <=> CO2(99) + C2H4O(183). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H4O(183) <=> CO2(99) + C2H4O(183). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H4O(183) <=> CO2(99) + C2H4O(183). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H4O(183) <=> CO2(99) + C2H4O(183). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CO2(14) <=> CO2(14) + CO2(99). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CO2(14) <=> CO2(14) + CO2(99). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HO2(9) + CH2CF2(42) <=> CF2-2(246) + CH3O2(59). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CO2(14) <=> CO2(14) + CO2(99). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CH2CO(25) <=> O2(2) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CH2CO(25) <=> O2(2) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CH2CO(25) <=> O2(2) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + C2H3FO(65) <=> O2(2) + C2H3FO(65). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + C2H4O(183) <=> O2(2) + C2H4O(183). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HO2(9) + CH2CO(25) <=> CO(13) + CH3O2(59). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HF(33) + HCCO(20) <=> S(323). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CH2CO(25) + CH2CFO(54) <=> HCCO(20) + C2H3FO(68). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CF2O(187) <=> O(7) + CF2O2(227). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CF2O(187) <=> O2(2) + CF2O(187). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H3FO(65) <=> CO2(99) + C2H3FO(65). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H3FO(65) <=> CO2(99) + C2H3FO(65). Not combining reactions.
# ...
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CF3CCH(98) <=> CO2(127) + CF3CCH(98). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CF3CCH(98) <=> CO2(127) + CF3CCH(98). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CF2O(46) + CH2O2(66) <=> H(5) + S(143). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HFO(124) <=> CO2(127) + C2HFO(124). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HFO(124) <=> CO2(127) + C2HFO(124). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HFO(124) <=> CO2(127) + C2HFO(124). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HFO(124) <=> CO2(127) + C2HFO(124). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HFO(124) <=> CO2(127) + C2HFO(124). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HFO(124) <=> CO2(127) + C2HFO(124). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HO2(10) + S(133) <=> CH2(196) + S(151). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H2(23) <=> CO2(127) + C2H2(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(141) <=> CO2(127) + S(141). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(141) <=> CO2(127) + S(141). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(141) <=> CO2(127) + S(141). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(141) <=> CO2(127) + S(141). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(141) <=> CO2(127) + S(141). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(141) <=> CO2(127) + S(141). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H4(29) <=> CO2(127) + C2H4(29). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(2) + C2HFO(124) <=> O2(57) + C2HFO(124). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C3HF3(132) <=> CO2(127) + C3HF3(132). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C3HF3(132) <=> CO2(127) + C3HF3(132). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C3HF3(132) <=> CO2(127) + C3HF3(132). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C3HF3(132) <=> CO2(127) + C3HF3(132). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C3HF3(132) <=> CO2(127) + C3HF3(132). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C3HF3(132) <=> CO2(127) + C3HF3(132). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C#CCF(161) <=> CO2(127) + C#CCF(161). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C#CCF(161) <=> CO2(127) + C#CCF(161). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C#CCF(161) <=> CO2(127) + C#CCF(161). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C#CCF(161) <=> CO2(127) + C#CCF(161). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C#CCF(161) <=> CO2(127) + C#CCF(161). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C#CCF(161) <=> CO2(127) + C#CCF(161). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(57) + CH2CO(27) <=> O2(2) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(57) + CH2CO(27) <=> O2(2) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(57) + CH2CO(27) <=> O2(2) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O2(66) <=> CO2(127) + CH2O2(66). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O2(66) <=> CO2(127) + CH2O2(66). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O2(66) <=> CO2(127) + CH2O2(66). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O2(66) <=> CO2(127) + CH2O2(66). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O2(66) <=> CO2(127) + CH2O2(66). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O2(66) <=> CO2(127) + CH2O2(66). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH3CHO(35) <=> CO2(127) + CH3CHO(35). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH3CHO(35) <=> CO2(127) + CH3CHO(35). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH3CHO(35) <=> CO2(127) + CH3CHO(35). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH3CHO(35) <=> CO2(127) + CH3CHO(35). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH3CHO(35) <=> CO2(127) + CH3CHO(35). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH3CHO(35) <=> CO2(127) + CH3CHO(35). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(57) + CF3CCH(98) <=> O2(2) + CF3CCH(98). Not combining reactions.
# CH3F is: CH3F(1)
# CH3CF3 is: CH3CF3(81)
# ******************************************

# %%
#let's save this to a dictionary that we can reference in functions below

mapping = dict()

for blend in blends_: 
    
    match = re.findall('([A-Z0-9]+)_([A-Z0-9]+)',blend)
    spec1 = match[0][0]
    spec2 = match[0][1]
    
    if len(match)>2:
        print(blend)
    
    
    direc = f'/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/blends_of_two_equal_parts_species_in_core_redo/{blend}/chemkin'
    spcs, rxns = rmgpy.chemkin.load_chemkin_file(f'{direc}/copies/copy_chem.inp',f'{direc}/species_dictionary.txt', f'{direc}/tran.dat' )
   
    for_this_blend=[]
    
    for species in spcs: 
        if species.smiles == smiles[spec1]: 
            for_this_blend.append(species.to_chemkin())
        if species.smiles == smiles[spec2]: 
            for_this_blend.append(species.to_chemkin())
    
    #did this in a separate list because I want to make sure O2 is last in the list
    for species in spcs: 
        if species.smiles == smiles['O2']: 
            for_this_blend.append(species.to_chemkin())
    
 
    #add to dictionary
    mapping[blend] = for_this_blend
    

print(mapping)
# Out:
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.falloff.Troe'> for duplicate reaction C2H3O(224) <=> CO(11) + CH3(16). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HO2(9) + CH2CHF(39) <=> CHF-2(226) + CH3O2(57). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H4(25) <=> CO2(97) + C2H4(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CHF(39) <=> CO2(97) + CH2CHF(39). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CHF(39) <=> CO2(97) + CH2CHF(39). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CHF(39) <=> CO2(97) + CH2CHF(39). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CHF(39) <=> CO2(97) + CH2CHF(39). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CHF(39) <=> CO2(97) + CH2CHF(39). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CHF(39) <=> CO2(97) + CH2CHF(39). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CO2(12) <=> CO2(12) + CO2(97). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CO2(12) <=> CO2(12) + CO2(97). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CO2(12) <=> CO2(12) + CO2(97). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CHFO(36) <=> CO2(97) + CHFO(36). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CHFO(36) <=> CO2(97) + CHFO(36). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CHFO(36) <=> CO2(97) + CHFO(36). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CHFO(36) <=> CO2(97) + CHFO(36). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CHFO(36) <=> CO2(97) + CHFO(36). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CHFO(36) <=> CO2(97) + CHFO(36). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H2(20) <=> CO2(97) + C2H2(20). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2O(17) <=> CO2(97) + CH2O(17). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2O(17) <=> CO2(97) + CH2O(17). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2O(17) <=> CO2(97) + CH2O(17). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CH2CHF(39) <=> O(7) + FC1CO1(76). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CH2CHF(39) <=> O2(2) + CH2CHF(39). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CF2O(181) <=> O(7) + CF2O2(195). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CF2O(181) <=> O(7) + CF2O2(209). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CF2O(181) <=> O2(2) + CF2O(181). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2O(17) <=> CO2(97) + CH2O(17). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2O(17) <=> CO2(97) + CH2O(17). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2O(17) <=> CO2(97) + CH2O(17). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CO2(12) <=> O2(2) + CO2(12). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CO2(12) <=> O2(2) + CO2(97). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CO(23) <=> CO2(97) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H4O(225) <=> CO2(97) + C2H4O(225). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H4O(225) <=> CO2(97) + C2H4O(225). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H4O(225) <=> CO2(97) + C2H4O(225). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H4O(225) <=> CO2(97) + C2H4O(225). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H4O(225) <=> CO2(97) + C2H4O(225). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H4O(225) <=> CO2(97) + C2H4O(225). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CF2O(181) + CO2(12) <=> CF2O(181) + CO2(97). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CF2O(181) + CO2(12) <=> CF2O(181) + CO2(97). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CF2O(181) + CO2(12) <=> CF2O(181) + CO2(97). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CF2O(181) + CO2(12) <=> CF2O(181) + CO2(97). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CF2O(181) + CO2(12) <=> CF2O(181) + CO2(97). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CF2O(181) + CO2(12) <=> CF2O(181) + CO2(97). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CHF2(53) + CH2CHF(39) <=> CHF-2(226) + C2H3F2(45). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CH2O(17) <=> O(7) + C1OO1(113). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CH2O(17) <=> O2(2) + CH2O(17). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CH2CO(23) + CH2CO(23) <=> HCCO(18) + C2H3O(224). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CHFO(36) + CH2CHF(39) <=> CHF(33) + C2H3FO(66). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CHFO(36) + CH2CHF(39) <=> CHF-2(226) + C2H3FO(66). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HF(31) + CO2(12) + CH2CO(23) <=> CHO2(60) + CH2CFO(52). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HF(31) + CO2(12) + CH2CO(23) <=> CO2(12) + C2H3FO(63). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF3(182) <=> CO2(97) + C2HF3(182). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF3(182) <=> CO2(97) + C2HF3(182). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF3(182) <=> CO2(97) + C2HF3(182). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF3(182) <=> CO2(97) + C2HF3(182). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF3(182) <=> CO2(97) + C2HF3(182). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF3(182) <=> CO2(97) + C2HF3(182). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CH2CO(23) <=> O2(2) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CH2CO(23) <=> O2(2) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CH2CO(23) <=> O2(2) + CH2CO(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H3FO(63) <=> CO2(97) + C2H3FO(63). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H3FO(63) <=> CO2(97) + C2H3FO(63). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H3FO(63) <=> CO2(97) + C2H3FO(63). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H3FO(63) <=> CO2(97) + C2H3FO(63). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H3FO(63) <=> CO2(97) + C2H3FO(63). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H3FO(63) <=> CO2(97) + C2H3FO(63). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF(41) <=> CO2(97) + C2HF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF(41) <=> CO2(97) + C2HF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF(41) <=> CO2(97) + C2HF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF(41) <=> CO2(97) + C2HF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF(41) <=> CO2(97) + C2HF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HF(41) <=> CO2(97) + C2HF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CF2O(181) + CH2CF2(40) <=> CF2(178) + S(214). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HO2(9) + CH2CO(23) <=> CO(11) + CH3O2(57). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CHF-2(226) + C2H2(20) <=> CH2(222) + C2HF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CHF-2(226) + C2H2(20) <=> F(30) + C3H3(102). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CHF-2(226) + C2H2(20) <=> H(6) + C3H2F(91). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + C2H3FO(63) <=> O2(2) + C2H3FO(63). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + C2H4O(225) <=> O2(2) + C2H4O(225). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + C2HF3(182) <=> O(7) + S(201). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + C2HF3(182) <=> O2(2) + C2HF3(182). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HO2(9) + C2HF3(182) <=> CHF-2(226) + CHF2O2(90). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CF2(40) <=> CO2(97) + CH2CF2(40). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CF2(40) <=> CO2(97) + CH2CF2(40). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CF2(40) <=> CO2(97) + CH2CF2(40). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CF2(40) <=> CO2(97) + CH2CF2(40). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CF2(40) <=> CO2(97) + CH2CF2(40). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + CH2CF2(40) <=> CO2(97) + CH2CF2(40). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HO2(9) + CH2CF2(40) <=> CHF2O2(90) + CH2(222). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2F4(183) <=> CO2(97) + C2F4(183). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CF2O(181) + CH2CF2(40) <=> CF2-2(227) + S(214). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HO2(9) + CH2CF2(40) <=> CF2-2(227) + CH3O2(57). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CHFO(36) <=> O(7) + CHFO2(189). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CHFO(36) <=> O2(2) + CHFO(36). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CH2CO(23) + CH2CFO(52) <=> HCCO(18) + C2H3FO(66). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + S(208) <=> CO2(97) + S(208). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2HFO(77) <=> CO2(97) + C2HFO(77). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HF(31) + HCCO(18) <=> S(300). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C2H2F2(42) <=> CO2(97) + C2H2F2(42). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CH2CF2(40) <=> O(7) + S(215). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + CH2CF2(40) <=> O2(2) + CH2CF2(40). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + C2HF(41) <=> O(7) + C2HFO(211). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(197) + C2HF(41) <=> O2(2) + C2HF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(12) + C4H4(104) <=> CO2(97) + C4H4(104). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.falloff.Troe'> for duplicate reaction C2H3O(182) <=> CO(13) + CH3(18). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HF(33) + C2HFO(79) <=> CO(13) + CH2F2(36). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO(13) + CH2F2(36) <=> F(32) + C2H2FO(80). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CHFO(38) + CH2CHF(41) <=> CHF(35) + C2H3FO(68). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CH2CHF(41) <=> O(7) + FC1CO1(78). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CH2CHF(41) <=> O2(2) + CH2CHF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CHF(41) <=> CO2(99) + CH2CHF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CHF(41) <=> CO2(99) + CH2CHF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CHF(41) <=> CO2(99) + CH2CHF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CHF(41) <=> CO2(99) + CH2CHF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CHF(41) <=> CO2(99) + CH2CHF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CHF(41) <=> CO2(99) + CH2CHF(41). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H4(27) <=> CO2(99) + C2H4(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H2F2(44) <=> CO2(99) + C2H2F2(44). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CF2(42) <=> CO2(99) + CH2CF2(42). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CF2(42) <=> CO2(99) + CH2CF2(42). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CF2(42) <=> CO2(99) + CH2CF2(42). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CF2(42) <=> CO2(99) + CH2CF2(42). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CF2(42) <=> CO2(99) + CH2CF2(42). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CF2(42) <=> CO2(99) + CH2CF2(42). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HO2(9) + CH2CF2(42) <=> CHF2O2(92) + CH2(244). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CH2CF2(42) <=> O(7) + S(203). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CH2CF2(42) <=> O2(2) + CH2CF2(42). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CHFO(38) <=> O(7) + CHFO2(210). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CHFO(38) <=> O2(2) + CHFO(38). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CHFO(38) <=> CO2(99) + CHFO(38). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CHFO(38) <=> CO2(99) + CHFO(38). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CHFO(38) <=> CO2(99) + CHFO(38). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CHFO(38) <=> CO2(99) + CHFO(38). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CHFO(38) <=> CO2(99) + CHFO(38). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CHFO(38) <=> CO2(99) + CHFO(38). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H2(22) <=> CO2(99) + C2H2(22). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CHFO(38) + C2H2F2(44) <=> CHF(35) + S(205). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HF(43) <=> CO2(99) + C2HF(43). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HF(43) <=> CO2(99) + C2HF(43). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HF(43) <=> CO2(99) + C2HF(43). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O(19) <=> CO2(99) + CH2O(19). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O(19) <=> CO2(99) + CH2O(19). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O(19) <=> CO2(99) + CH2O(19). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CH2O(19) <=> O(7) + C1OO1(115). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CH2O(19) <=> O2(2) + CH2O(19). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O(19) <=> CO2(99) + CH2O(19). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O(19) <=> CO2(99) + CH2O(19). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O(19) <=> CO2(99) + CH2O(19). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(25) <=> CO2(99) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HF(43) <=> CO2(99) + C2HF(43). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HF(43) <=> CO2(99) + C2HF(43). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HF(43) <=> CO2(99) + C2HF(43). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CH2CO(25) + CH2CO(25) <=> HCCO(20) + C2H3O(182). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H4O(183) <=> CO2(99) + C2H4O(183). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H4O(183) <=> CO2(99) + C2H4O(183). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H4O(183) <=> CO2(99) + C2H4O(183). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H4O(183) <=> CO2(99) + C2H4O(183). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H4O(183) <=> CO2(99) + C2H4O(183). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H4O(183) <=> CO2(99) + C2H4O(183). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CO2(14) <=> CO2(14) + CO2(99). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CO2(14) <=> CO2(14) + CO2(99). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HO2(9) + CH2CF2(42) <=> CF2-2(246) + CH3O2(59). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CO2(14) <=> CO2(14) + CO2(99). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CH2CO(25) <=> O2(2) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CH2CO(25) <=> O2(2) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CH2CO(25) <=> O2(2) + CH2CO(25). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + C2H3FO(65) <=> O2(2) + C2H3FO(65). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + C2H4O(183) <=> O2(2) + C2H4O(183). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HO2(9) + CH2CO(25) <=> CO(13) + CH3O2(59). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HF(33) + HCCO(20) <=> S(323). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CH2CO(25) + CH2CFO(54) <=> HCCO(20) + C2H3FO(68). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CF2O(187) <=> O(7) + CF2O2(227). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(196) + CF2O(187) <=> O2(2) + CF2O(187). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H3FO(65) <=> CO2(99) + C2H3FO(65). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H3FO(65) <=> CO2(99) + C2H3FO(65). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H3FO(65) <=> CO2(99) + C2H3FO(65). Not combining reactions.
# ...
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2CO(27) <=> CO2(127) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CF2O(46) + CH2O2(66) <=> H(5) + S(143). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HFO(124) <=> CO2(127) + C2HFO(124). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HFO(124) <=> CO2(127) + C2HFO(124). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HFO(124) <=> CO2(127) + C2HFO(124). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HFO(124) <=> CO2(127) + C2HFO(124). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HFO(124) <=> CO2(127) + C2HFO(124). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2HFO(124) <=> CO2(127) + C2HFO(124). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction HO2(10) + S(133) <=> CH2(196) + S(151). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H2(23) <=> CO2(127) + C2H2(23). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(141) <=> CO2(127) + S(141). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(141) <=> CO2(127) + S(141). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(141) <=> CO2(127) + S(141). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(141) <=> CO2(127) + S(141). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(141) <=> CO2(127) + S(141). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(141) <=> CO2(127) + S(141). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C2H4(29) <=> CO2(127) + C2H4(29). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(2) + C2HFO(124) <=> O2(57) + C2HFO(124). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + S(153) <=> CO2(127) + S(153). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C3HF3(132) <=> CO2(127) + C3HF3(132). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C3HF3(132) <=> CO2(127) + C3HF3(132). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C3HF3(132) <=> CO2(127) + C3HF3(132). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C3HF3(132) <=> CO2(127) + C3HF3(132). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C3HF3(132) <=> CO2(127) + C3HF3(132). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C3HF3(132) <=> CO2(127) + C3HF3(132). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C#CCF(161) <=> CO2(127) + C#CCF(161). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C#CCF(161) <=> CO2(127) + C#CCF(161). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C#CCF(161) <=> CO2(127) + C#CCF(161). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C#CCF(161) <=> CO2(127) + C#CCF(161). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C#CCF(161) <=> CO2(127) + C#CCF(161). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + C#CCF(161) <=> CO2(127) + C#CCF(161). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(57) + CH2CO(27) <=> O2(2) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(57) + CH2CO(27) <=> O2(2) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(57) + CH2CO(27) <=> O2(2) + CH2CO(27). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O2(66) <=> CO2(127) + CH2O2(66). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O2(66) <=> CO2(127) + CH2O2(66). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O2(66) <=> CO2(127) + CH2O2(66). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O2(66) <=> CO2(127) + CH2O2(66). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O2(66) <=> CO2(127) + CH2O2(66). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH2O2(66) <=> CO2(127) + CH2O2(66). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH3CHO(35) <=> CO2(127) + CH3CHO(35). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH3CHO(35) <=> CO2(127) + CH3CHO(35). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH3CHO(35) <=> CO2(127) + CH3CHO(35). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH3CHO(35) <=> CO2(127) + CH3CHO(35). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH3CHO(35) <=> CO2(127) + CH3CHO(35). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction CO2(14) + CH3CHO(35) <=> CO2(127) + CH3CHO(35). Not combining reactions.
# WARNING:root:Unexpected kinetics type <class 'rmgpy.kinetics.chebyshev.Chebyshev'> for duplicate reaction O2(57) + CF3CCH(98) <=> O2(2) + CF3CCH(98). Not combining reactions.
# {'C2H5F_CH2F2': ['C2H5F(1)', 'CH2F2(34)', 'O2(2)'], 'C2H5F_CH2FCH2F': ['C2H5F(1)', 'S(179)', 'O2(2)'], 'C2H5F_CH2FCHF2': ['C2H5F(1)', 'S(179)', 'O2(2)'], 'C2H5F_CH3CHF2': ['C2H5F(1)', 'S(179)', 'O2(2)'], 'C2H5F_CH3F': ['C2H5F(1)', 'CH3F(34)', 'O2(2)'], 'CH2F2_CH3CF3': ['CH2F2(1)', 'CH3CF3(87)', 'O2(2)'], 'CH2F2_CH3F': ['CH2F2(1)', 'CH3F(22)', 'O2(2)'], 'CH2FCH2F_CH2F2': ['C2H4F2(1)', 'CH2F2(40)', 'O2(2)'], 'CH3CF3_C2H5F': ['CH3CF3(1)', 'C2H5F(188)', 'O2(2)'], 'CH3CF3_CH2FCH2F': ['CH3CF3(1)', 'S(188)', 'O2(2)'], 'CH3CF3_CH2FCHF2': ['CH3CF3(1)', 'S(188)', 'O2(2)'], 'CH3CF3_CH3CHF2': ['CH3CF3(1)', 'S(188)', 'O2(2)'], 'CH3CHF2_CH2F2': ['CH3CHF2(1)', 'CH2F2(40)', 'O2(2)'], 'CH3CHF2_CH2FCHF2': ['CH3CHF2(1)', 'S(180)', 'O2(2)'], 'CH3F_CH3CF3': ['CH3F(1)', 'CH3CF3(81)', 'O2(2)']}

# %% [markdown]
# Make the flamespeed_calc script to go into the folder of the blends

# %%
import os 
import re 
import cantera as ct



def make_gas(blend_name):
    print(blend_name)
    block = \
    f'''
directory = '/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/blends_of_two_equal_parts_species_in_core_redo/{blend_name}/chemkin/copies/copy_chem.cti'
gas = ct.Solution(directory)
blend_name = '{blend_name}'

vol_frac_list = list(np.linspace(0.025, 0.25, 30))

results = dict()


#this part calculates the flame calcs for all of the vol_frac list, using the previous vol frac count as a guess for the current one
for i in  range(len(vol_frac_list)):
    try:

        string = f'****************************starting new volume fraction **************************'
        print(string)
        
        x = vol_frac_list[i]
        norm_ox = (1-x)*.21
'''
    return block

def make_vol_frac_dict(label_list,num):
    print(label_list)
    '''Makes a volume fraction dictionary, assuming there are equal parts fuel in the blend'''

    vol_frac_dict = \
    '''
        vol_frac_dict = {'''
    for label in label_list[:-1]:
        print(label)
        vol_frac_dict += f"'{label}': (x/{num}/norm_ox), "
    vol_frac_dict += f"'{label_list[-1]}':((1-x)*.21)/norm_ox, 'N2':((1-x)*0.79)/norm_ox"
    vol_frac_dict += '}'
    
    block2 = \
    '''
        gas.TPX = To, Po, vol_frac_dict
        width = 0.08
        flame = ct.FreeFlame(gas, width=width)
        flame.set_refine_criteria(ratio=3, slope=0.1, curve=0.1) 
        flame.max_time_step_count = 900
        loglevel = 1 
        try:
            if i!=0:
                d = f'data/{vol_frac_list[i-1]}.csv'
                if os.path.exists(d):  
                    arr2 = ct.SolutionArray(gas)
                    arr2.read_csv(d)
                    flame.set_initial_guess(data=arr2)
                    print(' initial guess has been set')
        except: 
            print('initial guess not set for this volume fraction')
        
        
        #"False" stops the calculation from retrying over and over
        flame.solve(loglevel=loglevel, auto=False)
        Su = flame.velocity[0]
        results[x] = Su
        sltn = flame.to_solution_array()
        df1 = sltn.to_pandas()
        df1.to_csv(f'data/{x}.csv', index=False)            
            
    except Exception as e: 
        print(f'********************passed volume fraction:{vol_frac_list[i]}, error: {e}*************************************')
        pass

vol_fracs = list(results.keys())
flame_speeds = list(results.values())


print("volume fractions are:")
print(vol_fracs)

print("flame speeds are:")
print(flame_speeds)

    
with open('blend_flamespeeds.csv', 'w+') as g:
    writers = csv.writer(g)
    writers.writerow(vol_fracs)
    writers.writerow(flame_speeds)
        
'''
    vol_frac_dict += block2
    return vol_frac_dict


def make_bash_script(label_list, time_limit, node):
    bash_script = f'''#!/bin/sh

#SBATCH --nodes=1
#SBATCH --time={time_limit}-00:00:00
#SBATCH --job-name=fc_{'_'.join(label_list[0:-1])}
#SBATCH --error=error_fc.slurm.log
#SBATCH --output=output_fc.slurm.log
##SBATCH --cpus-per-task=5
##SBATCH --mem-per-cpu=8Gb
##SBATCH --ntasks=1 
##SBATCH --array=1
#SBATCH --partition={node}

source activate cantera_env
python flame_speed_calc.py

'''
    return bash_script

# %%
def make_blends(list_of_blend_files, num, dictionary_of_species):
    """Proved with a list of blend files, 
    specify the number of fuel species in the blend (num), this will run flame speed calc on all of them.
    
    example: make_blend([list using os.listdir(directory)])
    """
    

    for file in list_of_blend_files: 
             
            
            
        flame_speed_calc = '''

from os import uname
import cantera as ct
import numpy as np
import pandas as pd
import os
import csv

print("Running Cantera Version: " + str(ct.__version__))

To = 298
Po = 1e5 # ct.one_atm

    '''    
            
            
        
        print(f'Now working on: {file}')

        #now make the damn thing
        flame_speed_calc += make_gas(file)
        flame_speed_calc += make_vol_frac_dict(mapping[file],num)
        bash_script = make_bash_script(mapping[file], '1', 'short')
        directory_to_put_script =f'/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/blends_of_two_equal_parts_species_in_core_redo/flamespeeds/{file}'
        with open(os.path.join(directory_to_put_script,f'flame_speed_calc.py'),'w') as f: 
            for l in flame_speed_calc: 
                f.write(l)
        with open(os.path.join(directory_to_put_script,f'flame_speed_run.sh'),'w') as f: 
            for l in bash_script: 
                f.write(l)
                
        os.makedirs(os.path.join(directory_to_put_script,'data'),exist_ok=True)

# %%
# flame_dir = '/work/westgroup/nora/Code/projects/halogens/refrigerants/blends/blends_of_two_equal_parts_species_in_core/flamespeeds/'



# list_of_blends = [file for file in os.listdir(flame_dir) if re.match('[A-Z0-9]+_[A-Z0-9]+', file)]

list_of_blends = ['C2H5F_CH2F2',
 'C2H5F_CH2FCH2F',
 'C2H5F_CH2FCHF2',
 'C2H5F_CH3CHF2',
 'C2H5F_CH3F',
 'CH2F2_CH3CF3',
 'CH2FCH2F_CH2F2',
 'CH2FCH2F_CH2FCHF2',
 'CH2FCH2F_CH3CHF2',
 'CH3CF3_C2H5F',
 'CH3CF3_CH2FCH2F',
 'CH3CF3_CH2FCHF2',
 'CH3CF3_CH3CHF2',
 'CH3CHF2_CH2F2',
 'CH3CHF2_CH2FCHF2',
 'CH3F_CH3CF3',
 'CH3F_CH3CHF2']

# %%
blends_
# Out:
# ['C2H5F_CH2F2',
#  'C2H5F_CH2FCH2F',
#  'C2H5F_CH2FCHF2',
#  'C2H5F_CH3CHF2',
#  'C2H5F_CH3F',
#  'CH2F2_CH3CF3',
#  'CH2F2_CH3F',
#  'CH2FCH2F_CH2F2',
#  'CH3CF3_C2H5F',
#  'CH3CF3_CH2FCH2F',
#  'CH3CF3_CH2FCHF2',
#  'CH3CF3_CH3CHF2',
#  'CH3CHF2_CH2F2',
#  'CH3CHF2_CH2FCHF2',
#  'CH3F_CH3CF3']

# %%
 
make_blends(blends_, 2, for_this_blend)
# Out:
# Now working on: C2H5F_CH2F2
# C2H5F_CH2F2
# ['C2H5F(1)', 'CH2F2(34)', 'O2(2)']
# C2H5F(1)
# CH2F2(34)
# Now working on: C2H5F_CH2FCH2F
# C2H5F_CH2FCH2F
# ['C2H5F(1)', 'S(179)', 'O2(2)']
# C2H5F(1)
# S(179)
# Now working on: C2H5F_CH2FCHF2
# C2H5F_CH2FCHF2
# ['C2H5F(1)', 'S(179)', 'O2(2)']
# C2H5F(1)
# S(179)
# Now working on: C2H5F_CH3CHF2
# C2H5F_CH3CHF2
# ['C2H5F(1)', 'S(179)', 'O2(2)']
# C2H5F(1)
# S(179)
# Now working on: C2H5F_CH3F
# C2H5F_CH3F
# ['C2H5F(1)', 'CH3F(34)', 'O2(2)']
# C2H5F(1)
# CH3F(34)
# Now working on: CH2F2_CH3CF3
# CH2F2_CH3CF3
# ['CH2F2(1)', 'CH3CF3(87)', 'O2(2)']
# CH2F2(1)
# CH3CF3(87)
# Now working on: CH2F2_CH3F
# CH2F2_CH3F
# ['CH2F2(1)', 'CH3F(22)', 'O2(2)']
# CH2F2(1)
# CH3F(22)
# Now working on: CH2FCH2F_CH2F2
# CH2FCH2F_CH2F2
# ['C2H4F2(1)', 'CH2F2(40)', 'O2(2)']
# C2H4F2(1)
# CH2F2(40)
# Now working on: CH3CF3_C2H5F
# CH3CF3_C2H5F
# ['CH3CF3(1)', 'C2H5F(188)', 'O2(2)']
# CH3CF3(1)
# C2H5F(188)
# Now working on: CH3CF3_CH2FCH2F
# CH3CF3_CH2FCH2F
# ['CH3CF3(1)', 'S(188)', 'O2(2)']
# CH3CF3(1)
# S(188)
# Now working on: CH3CF3_CH2FCHF2
# CH3CF3_CH2FCHF2
# ['CH3CF3(1)', 'S(188)', 'O2(2)']
# CH3CF3(1)
# S(188)
# Now working on: CH3CF3_CH3CHF2
# CH3CF3_CH3CHF2
# ['CH3CF3(1)', 'S(188)', 'O2(2)']
# CH3CF3(1)
# S(188)
# Now working on: CH3CHF2_CH2F2
# CH3CHF2_CH2F2
# ['CH3CHF2(1)', 'CH2F2(40)', 'O2(2)']
# CH3CHF2(1)
# CH2F2(40)
# Now working on: CH3CHF2_CH2FCHF2
# CH3CHF2_CH2FCHF2
# ['CH3CHF2(1)', 'S(180)', 'O2(2)']
# CH3CHF2(1)
# S(180)
# Now working on: CH3F_CH3CF3
# CH3F_CH3CF3
# ['CH3F(1)', 'CH3CF3(81)', 'O2(2)']
# CH3F(1)
# CH3CF3(81)

# %%
len(blends_)
# Out:
# 15
